# %%
class Point:
    def __init__(self,x, y):
        self.x = x
        self.y = y
        
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
        
    def __str__(self):
        return f"{self.x} {self.y}"

# %%
class Edge:
    def __init__(self,p1, p2):
        self.p1 = p1
        self.p2 = p2
        
    def __eq__(self, other):
        return self.x == other.x and self.y == other.y
        
    def __str__(self):
        return f"{self.p1} {self.p2}"

# %%
class Triangle:
    def __init__(self, a, b, c):
        self.a = a
        self.b = b
        self.c = c
        self.v1 = Edge(a, b)
        self.v2 = Edge(b, c)
        self.v3 = Edge(c, a)

# %%
import random

dots = []
for i in range(9):
    p = Point(random.randint(0, 9), random.randint(0, 9))
    dots.append(p)
    print(p)
# Out:
# 6 7
# 6 9
# 0 4
# 5 7
# 7 5
# 9 5
# 7 0
# 1 9
# 7 3

# %%
print(dots[0] == Point(3, 3))
# Out:
# False

# %%
from matplotlib import pyplot as plt

tr = Triangle(Point(4,5), Point(5, 6), Point(7,8))
print(tr.v1)
# Out:
# 4 5 5 6

# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt
import matplotlib.tri
import matplotlib.collections


class Delaunay:
    def __init__(self, center=(0, 0), radius=9999):
        center = np.asarray(center)
        self.coords = [center + radius * np.array((-1, -1)),
                       center + radius * np.array((+1, -1)),
                       center + radius * np.array((+1, +1)),
                       center + radius * np.array((-1, +1))]

        self.triangles = {}
        self.circles = {}

        t1 = (0, 1, 3)
        t2 = (2, 3, 1)
        self.triangles[t1] = [t2, None, None]
        self.triangles[t2] = [t1, None, None]

        for t in self.triangles:
            self.circles[t] = self.circum_center(t)

    def circum_center(self, tri):
        pts = np.asarray([self.coords[v] for v in tri])
        pts2 = np.dot(pts, pts.T)
        a = np.bmat([[2 * pts2, [[1],
                                 [1],
                                 [1]]],
                     [[[1, 1, 1, 0]]]])

        b = np.hstack((np.sum(pts * pts, axis=1), [1]))
        x = np.linalg.solve(a, b)
        bary_coords = x[:-1]
        center = np.dot(bary_coords, pts)

        radius = np.sum(np.square(pts[0] - center))
        return (center, radius)

    def inCircleFast(self, tri, p):
        center, radius = self.circles[tri]
        return np.sum(np.square(center - p)) <= radius

    def addPoint(self, p):
        p = np.asarray(p)
        idx = len(self.coords)
        print("coords[", idx,"] ->",p)
        self.coords.append(p)

        bad_triangles = []
        for temp in self.triangles:
            if self.inCircleFast(temp, p):
                bad_triangles.append(temp)

        boundary = []
        temp = bad_triangles[0]
        edge = 0
        while True:
            print('-'*10)
            print(f"temp: {temp}")
            tri_op = self.triangles[temp][edge]
            print(f'tri_op: {tri_op}')
            if tri_op not in bad_triangles:
                print("not in bad")
                boundary.append((temp[(edge + 1) % 3], temp[(edge - 1) % 3], tri_op))
                edge = (edge + 1) % 3
                print(f"edge: {edge}")
                print(f"boundary: {boundary}")
                if boundary[0][0] == boundary[-1][1]:
                    break
            else:
                print("in bad")
                edge = (self.triangles[tri_op].index(temp) + 1) % 3
                temp = tri_op
                print(f"edge: {edge}")
                print(f"temp: {temp}")

        print('-' * 10)
        for temp in bad_triangles:
            del self.triangles[temp]
            del self.circles[temp]

        new_triangles = []
        for (e0, e1, tri_op) in boundary:
            temp = (idx, e0, e1)
            self.circles[temp] = self.circum_center(temp)
            self.triangles[temp] = [tri_op, None, None]

            if tri_op:
                for i, neigh in enumerate(self.triangles[tri_op]):
                    if neigh:
                        if e1 in neigh and e0 in neigh:
                            self.triangles[tri_op][i] = temp

            new_triangles.append(temp)

        n = len(new_triangles)
        for i, temp in enumerate(new_triangles):
            self.triangles[temp][1] = new_triangles[(i + 1) % n]
            self.triangles[temp][2] = new_triangles[(i - 1) % n]

    def exportTriangles(self):
        return [(a - 4, b - 4, c - 4)
                for (a, b, c) in self.triangles if a > 3 and b > 3 and c > 3]

    def exportCircles(self):
        return [(self.circles[(a, b, c)][0], sqrt(self.circles[(a, b, c)][1]))
                for (a, b, c) in self.triangles if a > 3 and b > 3 and c > 3]


def plot_one(num_seeds, square_size, addCircles=False):
    seeds = square_size * np.random.random((num_seeds, 2))
    print("seeds:\n", seeds)
    print("BBox Min:", np.amin(seeds, axis=0),
          "Bbox Max: ", np.amax(seeds, axis=0))

    center = np.mean(seeds, axis=0)
    dt = Delaunay(center, 50 * square_size)

    for s in seeds:
        dt.addPoint(s)

    print(len(dt.exportTriangles()), "Delaunay triangles")

    fig, ax = plt.subplots()
    ax.margins(0.1)
    ax.set_aspect('equal')
    plt.axis([-1, square_size + 1, -1, square_size + 1])

    cx, cy = zip(*seeds)
    dt_tris = dt.exportTriangles()
    ax.triplot(matplotlib.tri.Triangulation(cx, cy, dt_tris))

    if addCircles:
        for c, r in dt.exportCircles():
            ax.add_artist(plt.Circle(c, r, color='k', fill=False, ls='dotted'))

    plt.show()


def step_by_step_plot(num_seeds, square_size, addCircles=False):
    seeds = square_size * np.random.random((num_seeds, 2))
    print("seeds:\n", seeds)
    print("BBox Min:", np.amin(seeds, axis=0),
          "Bbox Max: ", np.amax(seeds, axis=0))

    center = np.mean(seeds, axis=0)

    dt2 = Delaunay(center, 50 * square_size)
    for i, s in enumerate(seeds):
        print("Inserting seed", i, s)
        dt2.addPoint(s)
        if i > 1:
            fig, ax = plt.subplots()
            ax.margins(0.1)
            ax.set_aspect('equal')
            plt.axis([-1, square_size + 1, -1, square_size + 1])
            for i, v in enumerate(seeds):
                plt.annotate(i, xy=v)
            for t in dt2.exportTriangles():
                polygon = [seeds[i] for i in t]
                plt.fill(*zip(*polygon), fill=False, color="b")
                if addCircles:
                    for c, r in dt2.exportCircles():
                        ax.add_artist(plt.Circle(c, r, color='k', fill=False, ls='dotted'))
            plt.show()


if __name__ == '__main__':
    num_seeds = 50
    square_size = 1000

    plot_one(
        num_seeds=num_seeds,
        square_size=square_size,
        addCircles=True
    )

    step_by_step_plot(
        num_seeds=num_seeds,
        square_size=square_size,
        addCircles=False
    )
# Out:
# seeds:
#  [[172.10186953 507.78579135]
#  [629.53018307 700.79279946]
#  [350.86676902  23.85659535]
#  [583.01808028 726.79103362]
#  [446.3215746  792.73504147]
#  [462.15527838 688.53269669]
#  [688.74477171 496.16527741]
#  [ 55.3761161  976.41186667]
#  [487.42670381 108.85740833]
#  [570.79873653 652.52091508]
#  [ 74.62838013 232.31122765]
#  [412.75181153 994.98474178]
#  [975.27858092 498.52873327]
#  [568.86811869 900.66648492]
#  [694.64741497 394.5832161 ]
#  [880.212327   589.81803627]
#  [941.00033433  13.36175952]
#  [910.03882903 773.63543519]
#  [604.77955451 323.03512905]
#  [ 88.93969516 690.02900079]
#  [ 39.39589376 347.36282375]
#  [649.56104018 391.80110942]
#  [933.50371119 291.88996448]
#  [516.21953086 814.78141621]
#  [145.66507575 979.29433946]
#  [706.32590146 376.57093375]
#  [765.65789099 812.1120504 ]
#  [237.89002739 932.57374806]
#  [837.03815341 625.4170518 ]
#  [593.94913466 734.96286069]
#  [419.86610228 307.36426937]
#  [190.71154603  51.36171959]
#  [521.13153488 547.41809276]
#  [260.4129825  478.09468617]
#  [ 22.74626668 872.94803405]
#  [272.08372514 932.87086537]
#  [815.75929813 660.36657607]
#  [663.10683801  81.41444904]
#  [495.56446597 898.81253968]
#  [912.94343298 890.3269139 ]
#  [642.82476995 384.22586921]
#  [147.37648221 763.83396757]
#  [223.65053406 327.5882837 ]
#  [810.63986334 516.25578611]
#  [246.31303041 782.87741288]
#  [942.51864046 204.03021995]
#  [944.47038655 680.80770729]
#  [628.46876999 159.00108712]
#  [833.14944756 978.23481777]
#  [ 85.05092594 623.92059285]]
# BBox Min: [22.74626668 13.36175952] Bbox Max:  [975.27858092 994.98474178]
# coords[ 4 ] -> [172.10186953 507.78579135]
# ----------
# temp: (0, 1, 3)
# tri_op: (2, 3, 1)
# in bad
# edge: 1
# temp: (2, 3, 1)
# ----------
# temp: (2, 3, 1)
# tri_op: None
# not in bad
# edge: 2
# boundary: [(1, 2, None)]
# ----------
# temp: (2, 3, 1)
# tri_op: None
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 3, None)]
# ----------
# temp: (2, 3, 1)
# tri_op: (0, 1, 3)
# in bad
# edge: 1
# temp: (0, 1, 3)
# ----------
# temp: (0, 1, 3)
# tri_op: None
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 3, None), (3, 0, None)]
# ----------
# temp: (0, 1, 3)
# tri_op: None
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 3, None), (3, 0, None), (0, 1, None)]
# ----------
# coords[ 5 ] -> [629.53018307 700.79279946]
# ----------
# temp: (4, 1, 2)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(1, 2, None)]
# ----------
# temp: (4, 1, 2)
# tri_op: (4, 2, 3)
# in bad
# edge: 0
# temp: (4, 2, 3)
# ----------
# temp: (4, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(1, 2, None), (2, 3, None)]
# ----------
# temp: (4, 2, 3)
# tri_op: (4, 3, 0)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 3, None), (3, 4, (4, 3, 0))]
# ----------
# temp: (4, 2, 3)
# tri_op: (4, 1, 2)
# in bad
# edge: 2
# temp: (4, 1, 2)
# ----------
# temp: (4, 1, 2)
# tri_op: (4, 0, 1)
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 3, None), (3, 4, (4, 3, 0)), (4, 1, (4, 0, 1))]
# ----------
# coords[ 6 ] -> [350.86676902  23.85659535]
# ----------
# temp: (4, 0, 1)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(0, 1, None)]
# ----------
# temp: (4, 0, 1)
# tri_op: (5, 4, 1)
# in bad
# edge: 1
# temp: (5, 4, 1)
# ----------
# temp: (5, 4, 1)
# tri_op: (5, 1, 2)
# not in bad
# edge: 2
# boundary: [(0, 1, None), (1, 5, (5, 1, 2))]
# ----------
# temp: (5, 4, 1)
# tri_op: (5, 3, 4)
# not in bad
# edge: 0
# boundary: [(0, 1, None), (1, 5, (5, 1, 2)), (5, 4, (5, 3, 4))]
# ----------
# temp: (5, 4, 1)
# tri_op: (4, 0, 1)
# in bad
# edge: 2
# temp: (4, 0, 1)
# ----------
# temp: (4, 0, 1)
# tri_op: (4, 3, 0)
# not in bad
# edge: 0
# boundary: [(0, 1, None), (1, 5, (5, 1, 2)), (5, 4, (5, 3, 4)), (4, 0, (4, 3, 0))]
# ----------
# coords[ 7 ] -> [583.01808028 726.79103362]
# ----------
# temp: (5, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(2, 3, None)]
# ----------
# temp: (5, 2, 3)
# tri_op: (5, 3, 4)
# in bad
# edge: 0
# temp: (5, 3, 4)
# ----------
# temp: (5, 3, 4)
# tri_op: (4, 3, 0)
# not in bad
# edge: 1
# boundary: [(2, 3, None), (3, 4, (4, 3, 0))]
# ----------
# temp: (5, 3, 4)
# tri_op: (6, 5, 4)
# not in bad
# edge: 2
# boundary: [(2, 3, None), (3, 4, (4, 3, 0)), (4, 5, (6, 5, 4))]
# ----------
# temp: (5, 3, 4)
# tri_op: (5, 2, 3)
# in bad
# edge: 2
# temp: (5, 2, 3)
# ----------
# temp: (5, 2, 3)
# tri_op: (5, 1, 2)
# not in bad
# edge: 0
# boundary: [(2, 3, None), (3, 4, (4, 3, 0)), (4, 5, (6, 5, 4)), (5, 2, (5, 1, 2))]
# ----------
# coords[ 8 ] -> [446.3215746  792.73504147]
# ----------
# temp: (7, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(2, 3, None)]
# ----------
# temp: (7, 2, 3)
# tri_op: (7, 3, 4)
# in bad
# edge: 0
# temp: (7, 3, 4)
# ----------
# temp: (7, 3, 4)
# tri_op: (4, 3, 0)
# not in bad
# edge: 1
# boundary: [(2, 3, None), (3, 4, (4, 3, 0))]
# ----------
# temp: (7, 3, 4)
# tri_op: (7, 4, 5)
# not in bad
# edge: 2
# boundary: [(2, 3, None), (3, 4, (4, 3, 0)), (4, 7, (7, 4, 5))]
# ----------
# temp: (7, 3, 4)
# tri_op: (7, 2, 3)
# in bad
# edge: 2
# temp: (7, 2, 3)
# ----------
# temp: (7, 2, 3)
# tri_op: (7, 5, 2)
# not in bad
# edge: 0
# boundary: [(2, 3, None), (3, 4, (4, 3, 0)), (4, 7, (7, 4, 5)), (7, 2, (7, 5, 2))]
# ----------
# coords[ 9 ] -> [462.15527838 688.53269669]
# ----------
# temp: (6, 5, 4)
# tri_op: (7, 4, 5)
# in bad
# edge: 1
# temp: (7, 4, 5)
# ----------
# temp: (7, 4, 5)
# tri_op: (7, 5, 2)
# not in bad
# edge: 2
# boundary: [(5, 7, (7, 5, 2))]
# ----------
# temp: (7, 4, 5)
# tri_op: (8, 4, 7)
# in bad
# edge: 1
# temp: (8, 4, 7)
# ----------
# temp: (8, 4, 7)
# tri_op: (8, 7, 2)
# not in bad
# edge: 2
# boundary: [(5, 7, (7, 5, 2)), (7, 8, (8, 7, 2))]
# ----------
# temp: (8, 4, 7)
# tri_op: (8, 3, 4)
# not in bad
# edge: 0
# boundary: [(5, 7, (7, 5, 2)), (7, 8, (8, 7, 2)), (8, 4, (8, 3, 4))]
# ----------
# temp: (8, 4, 7)
# tri_op: (7, 4, 5)
# in bad
# edge: 0
# temp: (7, 4, 5)
# ----------
# temp: (7, 4, 5)
# tri_op: (6, 5, 4)
# in bad
# edge: 1
# temp: (6, 5, 4)
# ----------
# temp: (6, 5, 4)
# tri_op: (6, 4, 0)
# not in bad
# edge: 2
# boundary: [(5, 7, (7, 5, 2)), (7, 8, (8, 7, 2)), (8, 4, (8, 3, 4)), (4, 6, (6, 4, 0))]
# ----------
# temp: (6, 5, 4)
# tri_op: (6, 1, 5)
# not in bad
# edge: 0
# boundary: [(5, 7, (7, 5, 2)), (7, 8, (8, 7, 2)), (8, 4, (8, 3, 4)), (4, 6, (6, 4, 0)), (6, 5, (6, 1, 5))]
# ----------
# coords[ 10 ] -> [688.74477171 496.16527741]
# ----------
# temp: (5, 1, 2)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(1, 2, None)]
# ----------
# temp: (5, 1, 2)
# tri_op: (7, 5, 2)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 5, (7, 5, 2))]
# ----------
# temp: (5, 1, 2)
# tri_op: (6, 1, 5)
# in bad
# edge: 1
# temp: (6, 1, 5)
# ----------
# temp: (6, 1, 5)
# tri_op: (9, 6, 5)
# in bad
# edge: 1
# temp: (9, 6, 5)
# ----------
# temp: (9, 6, 5)
# tri_op: (9, 5, 7)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 5, (7, 5, 2)), (5, 9, (9, 5, 7))]
# ----------
# temp: (9, 6, 5)
# tri_op: (9, 4, 6)
# in bad
# edge: 2
# temp: (9, 4, 6)
# ----------
# temp: (9, 4, 6)
# tri_op: (9, 8, 4)
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 5, (7, 5, 2)), (5, 9, (9, 5, 7)), (9, 4, (9, 8, 4))]
# ----------
# temp: (9, 4, 6)
# tri_op: (6, 4, 0)
# not in bad
# edge: 1
# boundary: [(1, 2, None), (2, 5, (7, 5, 2)), (5, 9, (9, 5, 7)), (9, 4, (9, 8, 4)), (4, 6, (6, 4, 0))]
# ----------
# temp: (9, 4, 6)
# tri_op: (9, 6, 5)
# in bad
# edge: 0
# temp: (9, 6, 5)
# ----------
# temp: (9, 6, 5)
# tri_op: (6, 1, 5)
# in bad
# edge: 2
# temp: (6, 1, 5)
# ----------
# temp: (6, 1, 5)
# tri_op: (6, 0, 1)
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 5, (7, 5, 2)), (5, 9, (9, 5, 7)), (9, 4, (9, 8, 4)), (4, 6, (6, 4, 0)), (6, 1, (6, 0, 1))]
# ----------
# coords[ 11 ] -> [ 55.3761161  976.41186667]
# ----------
# temp: (4, 3, 0)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(3, 0, None)]
# ----------
# temp: (4, 3, 0)
# tri_op: (6, 4, 0)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 4, (6, 4, 0))]
# ----------
# temp: (4, 3, 0)
# tri_op: (8, 3, 4)
# in bad
# edge: 1
# temp: (8, 3, 4)
# ----------
# temp: (8, 3, 4)
# tri_op: (9, 8, 4)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 4, (6, 4, 0)), (4, 8, (9, 8, 4))]
# ----------
# temp: (8, 3, 4)
# tri_op: (8, 2, 3)
# in bad
# edge: 2
# temp: (8, 2, 3)
# ----------
# temp: (8, 2, 3)
# tri_op: (8, 7, 2)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 4, (6, 4, 0)), (4, 8, (9, 8, 4)), (8, 2, (8, 7, 2))]
# ----------
# temp: (8, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(3, 0, None), (0, 4, (6, 4, 0)), (4, 8, (9, 8, 4)), (8, 2, (8, 7, 2)), (2, 3, None)]
# ----------
# coords[ 12 ] -> [487.42670381 108.85740833]
# ----------
# temp: (10, 4, 6)
# tri_op: (6, 4, 0)
# not in bad
# edge: 1
# boundary: [(4, 6, (6, 4, 0))]
# ----------
# temp: (10, 4, 6)
# tri_op: (10, 6, 1)
# in bad
# edge: 0
# temp: (10, 6, 1)
# ----------
# temp: (10, 6, 1)
# tri_op: (6, 0, 1)
# not in bad
# edge: 1
# boundary: [(4, 6, (6, 4, 0)), (6, 1, (6, 0, 1))]
# ----------
# temp: (10, 6, 1)
# tri_op: (10, 1, 2)
# not in bad
# edge: 2
# boundary: [(4, 6, (6, 4, 0)), (6, 1, (6, 0, 1)), (1, 10, (10, 1, 2))]
# ----------
# temp: (10, 6, 1)
# tri_op: (10, 4, 6)
# in bad
# edge: 2
# temp: (10, 4, 6)
# ----------
# temp: (10, 4, 6)
# tri_op: (10, 9, 4)
# not in bad
# edge: 0
# boundary: [(4, 6, (6, 4, 0)), (6, 1, (6, 0, 1)), (1, 10, (10, 1, 2)), (10, 4, (10, 9, 4))]
# ----------
# coords[ 13 ] -> [570.79873653 652.52091508]
# ----------
# temp: (9, 5, 7)
# tri_op: (7, 5, 2)
# not in bad
# edge: 1
# boundary: [(5, 7, (7, 5, 2))]
# ----------
# temp: (9, 5, 7)
# tri_op: (9, 7, 8)
# not in bad
# edge: 2
# boundary: [(5, 7, (7, 5, 2)), (7, 9, (9, 7, 8))]
# ----------
# temp: (9, 5, 7)
# tri_op: (10, 5, 9)
# in bad
# edge: 1
# temp: (10, 5, 9)
# ----------
# temp: (10, 5, 9)
# tri_op: (10, 9, 4)
# not in bad
# edge: 2
# boundary: [(5, 7, (7, 5, 2)), (7, 9, (9, 7, 8)), (9, 10, (10, 9, 4))]
# ----------
# temp: (10, 5, 9)
# tri_op: (10, 2, 5)
# not in bad
# edge: 0
# boundary: [(5, 7, (7, 5, 2)), (7, 9, (9, 7, 8)), (9, 10, (10, 9, 4)), (10, 5, (10, 2, 5))]
# ----------
# coords[ 14 ] -> [ 74.62838013 232.31122765]
# ----------
# temp: (6, 4, 0)
# tri_op: (11, 0, 4)
# in bad
# edge: 1
# temp: (11, 0, 4)
# ----------
# temp: (11, 0, 4)
# tri_op: (11, 4, 8)
# not in bad
# edge: 2
# boundary: [(4, 11, (11, 4, 8))]
# ----------
# temp: (11, 0, 4)
# tri_op: (11, 3, 0)
# not in bad
# edge: 0
# boundary: [(4, 11, (11, 4, 8)), (11, 0, (11, 3, 0))]
# ----------
# temp: (11, 0, 4)
# tri_op: (6, 4, 0)
# in bad
# edge: 1
# temp: (6, 4, 0)
# ----------
# temp: (6, 4, 0)
# tri_op: (6, 0, 1)
# not in bad
# edge: 2
# boundary: [(4, 11, (11, 4, 8)), (11, 0, (11, 3, 0)), (0, 6, (6, 0, 1))]
# ----------
# temp: (6, 4, 0)
# tri_op: (12, 4, 6)
# in bad
# edge: 1
# temp: (12, 4, 6)
# ----------
# temp: (12, 4, 6)
# tri_op: (12, 6, 1)
# not in bad
# edge: 2
# boundary: [(4, 11, (11, 4, 8)), (11, 0, (11, 3, 0)), (0, 6, (6, 0, 1)), (6, 12, (12, 6, 1))]
# ----------
# temp: (12, 4, 6)
# tri_op: (12, 10, 4)
# not in bad
# edge: 0
# boundary: [(4, 11, (11, 4, 8)), (11, 0, (11, 3, 0)), (0, 6, (6, 0, 1)), (6, 12, (12, 6, 1)), (12, 4, (12, 10, 4))]
# ----------
# coords[ 15 ] -> [412.75181153 994.98474178]
# ----------
# temp: (7, 5, 2)
# tri_op: (10, 2, 5)
# not in bad
# edge: 1
# boundary: [(5, 2, (10, 2, 5))]
# ----------
# temp: (7, 5, 2)
# tri_op: (8, 7, 2)
# in bad
# edge: 1
# temp: (8, 7, 2)
# ----------
# temp: (8, 7, 2)
# tri_op: (11, 8, 2)
# in bad
# edge: 1
# temp: (11, 8, 2)
# ----------
# temp: (11, 8, 2)
# tri_op: (11, 2, 3)
# in bad
# edge: 0
# temp: (11, 2, 3)
# ----------
# temp: (11, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(5, 2, (10, 2, 5)), (2, 3, None)]
# ----------
# temp: (11, 2, 3)
# tri_op: (11, 3, 0)
# not in bad
# edge: 2
# boundary: [(5, 2, (10, 2, 5)), (2, 3, None), (3, 11, (11, 3, 0))]
# ----------
# temp: (11, 2, 3)
# tri_op: (11, 8, 2)
# in bad
# edge: 2
# temp: (11, 8, 2)
# ----------
# temp: (11, 8, 2)
# tri_op: (11, 4, 8)
# not in bad
# edge: 0
# boundary: [(5, 2, (10, 2, 5)), (2, 3, None), (3, 11, (11, 3, 0)), (11, 8, (11, 4, 8))]
# ----------
# temp: (11, 8, 2)
# tri_op: (8, 7, 2)
# in bad
# edge: 2
# temp: (8, 7, 2)
# ----------
# temp: (8, 7, 2)
# tri_op: (9, 7, 8)
# not in bad
# edge: 0
# boundary: [(5, 2, (10, 2, 5)), (2, 3, None), (3, 11, (11, 3, 0)), (11, 8, (11, 4, 8)), (8, 7, (9, 7, 8))]
# ----------
# temp: (8, 7, 2)
# tri_op: (7, 5, 2)
# in bad
# edge: 2
# temp: (7, 5, 2)
# ----------
# temp: (7, 5, 2)
# tri_op: (13, 5, 7)
# not in bad
# edge: 0
# boundary: [(5, 2, (10, 2, 5)), (2, 3, None), (3, 11, (11, 3, 0)), (11, 8, (11, 4, 8)), (8, 7, (9, 7, 8)), (7, 5, (13, 5, 7))]
# ----------
# coords[ 16 ] -> [975.27858092 498.52873327]
# ----------
# temp: (10, 1, 2)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(1, 2, None)]
# ----------
# temp: (10, 1, 2)
# tri_op: (10, 2, 5)
# in bad
# edge: 0
# temp: (10, 2, 5)
# ----------
# temp: (10, 2, 5)
# tri_op: (15, 5, 2)
# in bad
# edge: 1
# temp: (15, 5, 2)
# ----------
# temp: (15, 5, 2)
# tri_op: (15, 2, 3)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 15, (15, 2, 3))]
# ----------
# temp: (15, 5, 2)
# tri_op: (15, 7, 5)
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 15, (15, 2, 3)), (15, 5, (15, 7, 5))]
# ----------
# temp: (15, 5, 2)
# tri_op: (10, 2, 5)
# in bad
# edge: 1
# temp: (10, 2, 5)
# ----------
# temp: (10, 2, 5)
# tri_op: (13, 10, 5)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 15, (15, 2, 3)), (15, 5, (15, 7, 5)), (5, 10, (13, 10, 5))]
# ----------
# temp: (10, 2, 5)
# tri_op: (10, 1, 2)
# in bad
# edge: 2
# temp: (10, 1, 2)
# ----------
# temp: (10, 1, 2)
# tri_op: (12, 1, 10)
# in bad
# edge: 1
# temp: (12, 1, 10)
# ----------
# temp: (12, 1, 10)
# tri_op: (12, 10, 4)
# not in bad
# edge: 2
# boundary: [(1, 2, None), (2, 15, (15, 2, 3)), (15, 5, (15, 7, 5)), (5, 10, (13, 10, 5)), (10, 12, (12, 10, 4))]
# ----------
# temp: (12, 1, 10)
# tri_op: (12, 6, 1)
# not in bad
# edge: 0
# boundary: [(1, 2, None), (2, 15, (15, 2, 3)), (15, 5, (15, 7, 5)), (5, 10, (13, 10, 5)), (10, 12, (12, 10, 4)), (12, 1, (12, 6, 1))]
# ----------
# coords[ 17 ] -> [568.86811869 900.66648492]
# ----------
# temp: (15, 8, 7)
# tri_op: (9, 7, 8)
# not in bad
# edge: 1
# boundary: [(8, 7, (9, 7, 8))]
# ----------
# temp: (15, 8, 7)
# tri_op: (15, 7, 5)
# in bad
# edge: 0
# temp: (15, 7, 5)
# ----------
# temp: (15, 7, 5)
# tri_op: (13, 5, 7)
# not in bad
# edge: 1
# boundary: [(8, 7, (9, 7, 8)), (7, 5, (13, 5, 7))]
# ----------
# temp: (15, 7, 5)
# tri_op: (16, 15, 5)
# in bad
# edge: 1
# temp: (16, 15, 5)
# ----------
# temp: (16, 15, 5)
# tri_op: (16, 5, 10)
# not in bad
# edge: 2
# boundary: [(8, 7, (9, 7, 8)), (7, 5, (13, 5, 7)), (5, 16, (16, 5, 10))]
# ----------
# temp: (16, 15, 5)
# tri_op: (16, 2, 15)
# in bad
# edge: 2
# temp: (16, 2, 15)
# ----------
# temp: (16, 2, 15)
# tri_op: (16, 1, 2)
# not in bad
# edge: 0
# boundary: [(8, 7, (9, 7, 8)), (7, 5, (13, 5, 7)), (5, 16, (16, 5, 10)), (16, 2, (16, 1, 2))]
# ----------
# temp: (16, 2, 15)
# tri_op: (15, 2, 3)
# not in bad
# edge: 1
# boundary: [(8, 7, (9, 7, 8)), (7, 5, (13, 5, 7)), (5, 16, (16, 5, 10)), (16, 2, (16, 1, 2)), (2, 15, (15, 2, 3))]
# ----------
# temp: (16, 2, 15)
# tri_op: (16, 15, 5)
# in bad
# edge: 0
# temp: (16, 15, 5)
# ----------
# temp: (16, 15, 5)
# tri_op: (15, 7, 5)
# in bad
# edge: 2
# temp: (15, 7, 5)
# ----------
# temp: (15, 7, 5)
# tri_op: (15, 8, 7)
# in bad
# edge: 2
# temp: (15, 8, 7)
# ----------
# temp: (15, 8, 7)
# tri_op: (15, 11, 8)
# not in bad
# edge: 0
# boundary: [(8, 7, (9, 7, 8)), (7, 5, (13, 5, 7)), (5, 16, (16, 5, 10)), (16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 8, (15, 11, 8))]
# ----------
# coords[ 18 ] -> [694.64741497 394.5832161 ]
# ----------
# temp: (10, 9, 4)
# tri_op: (9, 8, 4)
# not in bad
# edge: 1
# boundary: [(9, 4, (9, 8, 4))]
# ----------
# temp: (10, 9, 4)
# tri_op: (12, 10, 4)
# in bad
# edge: 1
# temp: (12, 10, 4)
# ----------
# temp: (12, 10, 4)
# tri_op: (14, 12, 4)
# not in bad
# edge: 2
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4))]
# ----------
# temp: (12, 10, 4)
# tri_op: (16, 10, 12)
# in bad
# edge: 1
# temp: (16, 10, 12)
# ----------
# temp: (16, 10, 12)
# tri_op: (16, 12, 1)
# not in bad
# edge: 2
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 16, (16, 12, 1))]
# ----------
# temp: (16, 10, 12)
# tri_op: (16, 5, 10)
# not in bad
# edge: 0
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 16, (16, 12, 1)), (16, 10, (16, 5, 10))]
# ----------
# temp: (16, 10, 12)
# tri_op: (12, 10, 4)
# in bad
# edge: 0
# temp: (12, 10, 4)
# ----------
# temp: (12, 10, 4)
# tri_op: (10, 9, 4)
# in bad
# edge: 2
# temp: (10, 9, 4)
# ----------
# temp: (10, 9, 4)
# tri_op: (13, 9, 10)
# in bad
# edge: 1
# temp: (13, 9, 10)
# ----------
# temp: (13, 9, 10)
# tri_op: (13, 10, 5)
# not in bad
# edge: 2
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 16, (16, 12, 1)), (16, 10, (16, 5, 10)), (10, 13, (13, 10, 5))]
# ----------
# temp: (13, 9, 10)
# tri_op: (13, 7, 9)
# not in bad
# edge: 0
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 16, (16, 12, 1)), (16, 10, (16, 5, 10)), (10, 13, (13, 10, 5)), (13, 9, (13, 7, 9))]
# ----------
# coords[ 19 ] -> [880.212327   589.81803627]
# ----------
# temp: (16, 5, 10)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5))]
# ----------
# temp: (16, 5, 10)
# tri_op: (18, 16, 10)
# in bad
# edge: 1
# temp: (18, 16, 10)
# ----------
# temp: (18, 16, 10)
# tri_op: (18, 10, 13)
# not in bad
# edge: 2
# boundary: [(5, 10, (13, 10, 5)), (10, 18, (18, 10, 13))]
# ----------
# temp: (18, 16, 10)
# tri_op: (18, 12, 16)
# not in bad
# edge: 0
# boundary: [(5, 10, (13, 10, 5)), (10, 18, (18, 10, 13)), (18, 16, (18, 12, 16))]
# ----------
# temp: (18, 16, 10)
# tri_op: (16, 5, 10)
# in bad
# edge: 2
# temp: (16, 5, 10)
# ----------
# temp: (16, 5, 10)
# tri_op: (17, 5, 16)
# in bad
# edge: 1
# temp: (17, 5, 16)
# ----------
# temp: (17, 5, 16)
# tri_op: (17, 16, 2)
# not in bad
# edge: 2
# boundary: [(5, 10, (13, 10, 5)), (10, 18, (18, 10, 13)), (18, 16, (18, 12, 16)), (16, 17, (17, 16, 2))]
# ----------
# temp: (17, 5, 16)
# tri_op: (17, 7, 5)
# not in bad
# edge: 0
# boundary: [(5, 10, (13, 10, 5)), (10, 18, (18, 10, 13)), (18, 16, (18, 12, 16)), (16, 17, (17, 16, 2)), (17, 5, (17, 7, 5))]
# ----------
# coords[ 20 ] -> [941.00033433  13.36175952]
# ----------
# temp: (6, 0, 1)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(0, 1, None)]
# ----------
# temp: (6, 0, 1)
# tri_op: (12, 6, 1)
# in bad
# edge: 1
# temp: (12, 6, 1)
# ----------
# temp: (12, 6, 1)
# tri_op: (16, 12, 1)
# in bad
# edge: 1
# temp: (16, 12, 1)
# ----------
# temp: (16, 12, 1)
# tri_op: (16, 1, 2)
# not in bad
# edge: 2
# boundary: [(0, 1, None), (1, 16, (16, 1, 2))]
# ----------
# temp: (16, 12, 1)
# tri_op: (18, 12, 16)
# in bad
# edge: 1
# temp: (18, 12, 16)
# ----------
# temp: (18, 12, 16)
# tri_op: (19, 18, 16)
# not in bad
# edge: 2
# boundary: [(0, 1, None), (1, 16, (16, 1, 2)), (16, 18, (19, 18, 16))]
# ----------
# temp: (18, 12, 16)
# tri_op: (18, 4, 12)
# not in bad
# edge: 0
# boundary: [(0, 1, None), (1, 16, (16, 1, 2)), (16, 18, (19, 18, 16)), (18, 12, (18, 4, 12))]
# ----------
# temp: (18, 12, 16)
# tri_op: (16, 12, 1)
# in bad
# edge: 0
# temp: (16, 12, 1)
# ----------
# temp: (16, 12, 1)
# tri_op: (12, 6, 1)
# in bad
# edge: 2
# temp: (12, 6, 1)
# ----------
# temp: (12, 6, 1)
# tri_op: (14, 6, 12)
# not in bad
# edge: 0
# boundary: [(0, 1, None), (1, 16, (16, 1, 2)), (16, 18, (19, 18, 16)), (18, 12, (18, 4, 12)), (12, 6, (14, 6, 12))]
# ----------
# temp: (12, 6, 1)
# tri_op: (6, 0, 1)
# in bad
# edge: 2
# temp: (6, 0, 1)
# ----------
# temp: (6, 0, 1)
# tri_op: (14, 0, 6)
# not in bad
# edge: 0
# boundary: [(0, 1, None), (1, 16, (16, 1, 2)), (16, 18, (19, 18, 16)), (18, 12, (18, 4, 12)), (12, 6, (14, 6, 12)), (6, 0, (14, 0, 6))]
# ----------
# coords[ 21 ] -> [910.03882903 773.63543519]
# ----------
# temp: (17, 16, 2)
# tri_op: (16, 1, 2)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2))]
# ----------
# temp: (17, 16, 2)
# tri_op: (17, 2, 15)
# in bad
# edge: 0
# temp: (17, 2, 15)
# ----------
# temp: (17, 2, 15)
# tri_op: (15, 2, 3)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3))]
# ----------
# temp: (17, 2, 15)
# tri_op: (17, 15, 8)
# not in bad
# edge: 2
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (17, 15, 8))]
# ----------
# temp: (17, 2, 15)
# tri_op: (17, 16, 2)
# in bad
# edge: 2
# temp: (17, 16, 2)
# ----------
# temp: (17, 16, 2)
# tri_op: (19, 16, 17)
# in bad
# edge: 1
# temp: (19, 16, 17)
# ----------
# temp: (19, 16, 17)
# tri_op: (19, 17, 5)
# in bad
# edge: 0
# temp: (19, 17, 5)
# ----------
# temp: (19, 17, 5)
# tri_op: (17, 7, 5)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (17, 15, 8)), (17, 5, (17, 7, 5))]
# ----------
# temp: (19, 17, 5)
# tri_op: (19, 5, 10)
# not in bad
# edge: 2
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (17, 15, 8)), (17, 5, (17, 7, 5)), (5, 19, (19, 5, 10))]
# ----------
# temp: (19, 17, 5)
# tri_op: (19, 16, 17)
# in bad
# edge: 2
# temp: (19, 16, 17)
# ----------
# temp: (19, 16, 17)
# tri_op: (19, 18, 16)
# not in bad
# edge: 0
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (17, 15, 8)), (17, 5, (17, 7, 5)), (5, 19, (19, 5, 10)), (19, 16, (19, 18, 16))]
# ----------
# coords[ 22 ] -> [604.77955451 323.03512905]
# ----------
# temp: (18, 9, 4)
# tri_op: (9, 8, 4)
# not in bad
# edge: 1
# boundary: [(9, 4, (9, 8, 4))]
# ----------
# temp: (18, 9, 4)
# tri_op: (18, 4, 12)
# in bad
# edge: 0
# temp: (18, 4, 12)
# ----------
# temp: (18, 4, 12)
# tri_op: (14, 12, 4)
# not in bad
# edge: 1
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4))]
# ----------
# temp: (18, 4, 12)
# tri_op: (20, 18, 12)
# in bad
# edge: 1
# temp: (20, 18, 12)
# ----------
# temp: (20, 18, 12)
# tri_op: (20, 12, 6)
# not in bad
# edge: 2
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 20, (20, 12, 6))]
# ----------
# temp: (20, 18, 12)
# tri_op: (20, 16, 18)
# not in bad
# edge: 0
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 20, (20, 12, 6)), (20, 18, (20, 16, 18))]
# ----------
# temp: (20, 18, 12)
# tri_op: (18, 4, 12)
# in bad
# edge: 2
# temp: (18, 4, 12)
# ----------
# temp: (18, 4, 12)
# tri_op: (18, 9, 4)
# in bad
# edge: 2
# temp: (18, 9, 4)
# ----------
# temp: (18, 9, 4)
# tri_op: (18, 13, 9)
# in bad
# edge: 2
# temp: (18, 13, 9)
# ----------
# temp: (18, 13, 9)
# tri_op: (18, 10, 13)
# in bad
# edge: 2
# temp: (18, 10, 13)
# ----------
# temp: (18, 10, 13)
# tri_op: (19, 10, 18)
# not in bad
# edge: 0
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 20, (20, 12, 6)), (20, 18, (20, 16, 18)), (18, 10, (19, 10, 18))]
# ----------
# temp: (18, 10, 13)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 20, (20, 12, 6)), (20, 18, (20, 16, 18)), (18, 10, (19, 10, 18)), (10, 13, (13, 10, 5))]
# ----------
# temp: (18, 10, 13)
# tri_op: (18, 13, 9)
# in bad
# edge: 0
# temp: (18, 13, 9)
# ----------
# temp: (18, 13, 9)
# tri_op: (13, 7, 9)
# not in bad
# edge: 1
# boundary: [(9, 4, (9, 8, 4)), (4, 12, (14, 12, 4)), (12, 20, (20, 12, 6)), (20, 18, (20, 16, 18)), (18, 10, (19, 10, 18)), (10, 13, (13, 10, 5)), (13, 9, (13, 7, 9))]
# ----------
# coords[ 23 ] -> [ 88.93969516 690.02900079]
# ----------
# temp: (9, 8, 4)
# tri_op: (11, 4, 8)
# in bad
# edge: 1
# temp: (11, 4, 8)
# ----------
# temp: (11, 4, 8)
# tri_op: (15, 11, 8)
# not in bad
# edge: 2
# boundary: [(8, 11, (15, 11, 8))]
# ----------
# temp: (11, 4, 8)
# tri_op: (14, 4, 11)
# in bad
# edge: 1
# temp: (14, 4, 11)
# ----------
# temp: (14, 4, 11)
# tri_op: (14, 11, 0)
# not in bad
# edge: 2
# boundary: [(8, 11, (15, 11, 8)), (11, 14, (14, 11, 0))]
# ----------
# temp: (14, 4, 11)
# tri_op: (14, 12, 4)
# not in bad
# edge: 0
# boundary: [(8, 11, (15, 11, 8)), (11, 14, (14, 11, 0)), (14, 4, (14, 12, 4))]
# ----------
# temp: (14, 4, 11)
# tri_op: (11, 4, 8)
# in bad
# edge: 0
# temp: (11, 4, 8)
# ----------
# temp: (11, 4, 8)
# tri_op: (9, 8, 4)
# in bad
# edge: 1
# temp: (9, 8, 4)
# ----------
# temp: (9, 8, 4)
# tri_op: (22, 9, 4)
# not in bad
# edge: 2
# boundary: [(8, 11, (15, 11, 8)), (11, 14, (14, 11, 0)), (14, 4, (14, 12, 4)), (4, 9, (22, 9, 4))]
# ----------
# temp: (9, 8, 4)
# tri_op: (9, 7, 8)
# not in bad
# edge: 0
# boundary: [(8, 11, (15, 11, 8)), (11, 14, (14, 11, 0)), (14, 4, (14, 12, 4)), (4, 9, (22, 9, 4)), (9, 8, (9, 7, 8))]
# ----------
# coords[ 24 ] -> [ 39.39589376 347.36282375]
# ----------
# temp: (11, 3, 0)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(3, 0, None)]
# ----------
# temp: (11, 3, 0)
# tri_op: (14, 11, 0)
# in bad
# edge: 1
# temp: (14, 11, 0)
# ----------
# temp: (14, 11, 0)
# tri_op: (14, 0, 6)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 14, (14, 0, 6))]
# ----------
# temp: (14, 11, 0)
# tri_op: (23, 11, 14)
# in bad
# edge: 1
# temp: (23, 11, 14)
# ----------
# temp: (23, 11, 14)
# tri_op: (23, 14, 4)
# in bad
# edge: 0
# temp: (23, 14, 4)
# ----------
# temp: (23, 14, 4)
# tri_op: (14, 12, 4)
# not in bad
# edge: 1
# boundary: [(3, 0, None), (0, 14, (14, 0, 6)), (14, 4, (14, 12, 4))]
# ----------
# temp: (23, 14, 4)
# tri_op: (23, 4, 9)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 14, (14, 0, 6)), (14, 4, (14, 12, 4)), (4, 23, (23, 4, 9))]
# ----------
# temp: (23, 14, 4)
# tri_op: (23, 11, 14)
# in bad
# edge: 2
# temp: (23, 11, 14)
# ----------
# temp: (23, 11, 14)
# tri_op: (23, 8, 11)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 14, (14, 0, 6)), (14, 4, (14, 12, 4)), (4, 23, (23, 4, 9)), (23, 11, (23, 8, 11))]
# ----------
# temp: (23, 11, 14)
# tri_op: (14, 11, 0)
# in bad
# edge: 0
# temp: (14, 11, 0)
# ----------
# temp: (14, 11, 0)
# tri_op: (11, 3, 0)
# in bad
# edge: 2
# temp: (11, 3, 0)
# ----------
# temp: (11, 3, 0)
# tri_op: (15, 3, 11)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 14, (14, 0, 6)), (14, 4, (14, 12, 4)), (4, 23, (23, 4, 9)), (23, 11, (23, 8, 11)), (11, 3, (15, 3, 11))]
# ----------
# coords[ 25 ] -> [649.56104018 391.80110942]
# ----------
# temp: (22, 18, 10)
# tri_op: (19, 10, 18)
# not in bad
# edge: 1
# boundary: [(18, 10, (19, 10, 18))]
# ----------
# temp: (22, 18, 10)
# tri_op: (22, 10, 13)
# in bad
# edge: 0
# temp: (22, 10, 13)
# ----------
# temp: (22, 10, 13)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(18, 10, (19, 10, 18)), (10, 13, (13, 10, 5))]
# ----------
# temp: (22, 10, 13)
# tri_op: (22, 13, 9)
# in bad
# edge: 0
# temp: (22, 13, 9)
# ----------
# temp: (22, 13, 9)
# tri_op: (13, 7, 9)
# not in bad
# edge: 1
# boundary: [(18, 10, (19, 10, 18)), (10, 13, (13, 10, 5)), (13, 9, (13, 7, 9))]
# ----------
# temp: (22, 13, 9)
# tri_op: (22, 9, 4)
# not in bad
# edge: 2
# boundary: [(18, 10, (19, 10, 18)), (10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 22, (22, 9, 4))]
# ----------
# temp: (22, 13, 9)
# tri_op: (22, 10, 13)
# in bad
# edge: 2
# temp: (22, 10, 13)
# ----------
# temp: (22, 10, 13)
# tri_op: (22, 18, 10)
# in bad
# edge: 2
# temp: (22, 18, 10)
# ----------
# temp: (22, 18, 10)
# tri_op: (22, 20, 18)
# not in bad
# edge: 0
# boundary: [(18, 10, (19, 10, 18)), (10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 22, (22, 9, 4)), (22, 18, (22, 20, 18))]
# ----------
# coords[ 26 ] -> [933.50371119 291.88996448]
# ----------
# temp: (20, 16, 18)
# tri_op: (19, 18, 16)
# not in bad
# edge: 1
# boundary: [(16, 18, (19, 18, 16))]
# ----------
# temp: (20, 16, 18)
# tri_op: (22, 20, 18)
# in bad
# edge: 1
# temp: (22, 20, 18)
# ----------
# temp: (22, 20, 18)
# tri_op: (25, 22, 18)
# not in bad
# edge: 2
# boundary: [(16, 18, (19, 18, 16)), (18, 22, (25, 22, 18))]
# ----------
# temp: (22, 20, 18)
# tri_op: (22, 12, 20)
# not in bad
# edge: 0
# boundary: [(16, 18, (19, 18, 16)), (18, 22, (25, 22, 18)), (22, 20, (22, 12, 20))]
# ----------
# temp: (22, 20, 18)
# tri_op: (20, 16, 18)
# in bad
# edge: 2
# temp: (20, 16, 18)
# ----------
# temp: (20, 16, 18)
# tri_op: (20, 1, 16)
# not in bad
# edge: 0
# boundary: [(16, 18, (19, 18, 16)), (18, 22, (25, 22, 18)), (22, 20, (22, 12, 20)), (20, 16, (20, 1, 16))]
# ----------
# coords[ 27 ] -> [516.21953086 814.78141621]
# ----------
# temp: (9, 7, 8)
# tri_op: (17, 8, 7)
# in bad
# edge: 1
# temp: (17, 8, 7)
# ----------
# temp: (17, 8, 7)
# tri_op: (17, 7, 5)
# not in bad
# edge: 2
# boundary: [(7, 17, (17, 7, 5))]
# ----------
# temp: (17, 8, 7)
# tri_op: (17, 15, 8)
# in bad
# edge: 2
# temp: (17, 15, 8)
# ----------
# temp: (17, 15, 8)
# tri_op: (21, 15, 17)
# not in bad
# edge: 0
# boundary: [(7, 17, (17, 7, 5)), (17, 15, (21, 15, 17))]
# ----------
# temp: (17, 15, 8)
# tri_op: (15, 11, 8)
# not in bad
# edge: 1
# boundary: [(7, 17, (17, 7, 5)), (17, 15, (21, 15, 17)), (15, 8, (15, 11, 8))]
# ----------
# temp: (17, 15, 8)
# tri_op: (17, 8, 7)
# in bad
# edge: 0
# temp: (17, 8, 7)
# ----------
# temp: (17, 8, 7)
# tri_op: (9, 7, 8)
# in bad
# edge: 1
# temp: (9, 7, 8)
# ----------
# temp: (9, 7, 8)
# tri_op: (23, 9, 8)
# not in bad
# edge: 2
# boundary: [(7, 17, (17, 7, 5)), (17, 15, (21, 15, 17)), (15, 8, (15, 11, 8)), (8, 9, (23, 9, 8))]
# ----------
# temp: (9, 7, 8)
# tri_op: (13, 7, 9)
# not in bad
# edge: 0
# boundary: [(7, 17, (17, 7, 5)), (17, 15, (21, 15, 17)), (15, 8, (15, 11, 8)), (8, 9, (23, 9, 8)), (9, 7, (13, 7, 9))]
# ----------
# coords[ 28 ] -> [145.66507575 979.29433946]
# ----------
# temp: (15, 11, 8)
# tri_op: (23, 8, 11)
# in bad
# edge: 1
# temp: (23, 8, 11)
# ----------
# temp: (23, 8, 11)
# tri_op: (24, 23, 11)
# not in bad
# edge: 2
# boundary: [(11, 23, (24, 23, 11))]
# ----------
# temp: (23, 8, 11)
# tri_op: (23, 9, 8)
# not in bad
# edge: 0
# boundary: [(11, 23, (24, 23, 11)), (23, 8, (23, 9, 8))]
# ----------
# temp: (23, 8, 11)
# tri_op: (15, 11, 8)
# in bad
# edge: 1
# temp: (15, 11, 8)
# ----------
# temp: (15, 11, 8)
# tri_op: (27, 15, 8)
# not in bad
# edge: 2
# boundary: [(11, 23, (24, 23, 11)), (23, 8, (23, 9, 8)), (8, 15, (27, 15, 8))]
# ----------
# temp: (15, 11, 8)
# tri_op: (15, 3, 11)
# not in bad
# edge: 0
# boundary: [(11, 23, (24, 23, 11)), (23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 11, (15, 3, 11))]
# ----------
# coords[ 29 ] -> [706.32590146 376.57093375]
# ----------
# temp: (19, 10, 18)
# tri_op: (25, 18, 10)
# not in bad
# edge: 1
# boundary: [(10, 18, (25, 18, 10))]
# ----------
# temp: (19, 10, 18)
# tri_op: (19, 18, 16)
# in bad
# edge: 0
# temp: (19, 18, 16)
# ----------
# temp: (19, 18, 16)
# tri_op: (26, 16, 18)
# in bad
# edge: 1
# temp: (26, 16, 18)
# ----------
# temp: (26, 16, 18)
# tri_op: (26, 18, 22)
# in bad
# edge: 0
# temp: (26, 18, 22)
# ----------
# temp: (26, 18, 22)
# tri_op: (25, 22, 18)
# in bad
# edge: 1
# temp: (25, 22, 18)
# ----------
# temp: (25, 22, 18)
# tri_op: (25, 18, 10)
# not in bad
# edge: 2
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10))]
# ----------
# temp: (25, 22, 18)
# tri_op: (25, 9, 22)
# not in bad
# edge: 0
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10)), (25, 22, (25, 9, 22))]
# ----------
# temp: (25, 22, 18)
# tri_op: (26, 18, 22)
# in bad
# edge: 1
# temp: (26, 18, 22)
# ----------
# temp: (26, 18, 22)
# tri_op: (26, 22, 20)
# not in bad
# edge: 2
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10)), (25, 22, (25, 9, 22)), (22, 26, (26, 22, 20))]
# ----------
# temp: (26, 18, 22)
# tri_op: (26, 16, 18)
# in bad
# edge: 2
# temp: (26, 16, 18)
# ----------
# temp: (26, 16, 18)
# tri_op: (26, 20, 16)
# not in bad
# edge: 0
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10)), (25, 22, (25, 9, 22)), (22, 26, (26, 22, 20)), (26, 16, (26, 20, 16))]
# ----------
# temp: (26, 16, 18)
# tri_op: (19, 18, 16)
# in bad
# edge: 1
# temp: (19, 18, 16)
# ----------
# temp: (19, 18, 16)
# tri_op: (21, 19, 16)
# not in bad
# edge: 2
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10)), (25, 22, (25, 9, 22)), (22, 26, (26, 22, 20)), (26, 16, (26, 20, 16)), (16, 19, (21, 19, 16))]
# ----------
# temp: (19, 18, 16)
# tri_op: (19, 10, 18)
# in bad
# edge: 2
# temp: (19, 10, 18)
# ----------
# temp: (19, 10, 18)
# tri_op: (19, 5, 10)
# not in bad
# edge: 0
# boundary: [(10, 18, (25, 18, 10)), (18, 25, (25, 18, 10)), (25, 22, (25, 9, 22)), (22, 26, (26, 22, 20)), (26, 16, (26, 20, 16)), (16, 19, (21, 19, 16)), (19, 10, (19, 5, 10))]
# ----------
# coords[ 30 ] -> [765.65789099 812.1120504 ]
# ----------
# temp: (17, 7, 5)
# tri_op: (13, 5, 7)
# not in bad
# edge: 1
# boundary: [(7, 5, (13, 5, 7))]
# ----------
# temp: (17, 7, 5)
# tri_op: (21, 17, 5)
# in bad
# edge: 1
# temp: (21, 17, 5)
# ----------
# temp: (21, 17, 5)
# tri_op: (21, 5, 19)
# in bad
# edge: 0
# temp: (21, 5, 19)
# ----------
# temp: (21, 5, 19)
# tri_op: (19, 5, 10)
# not in bad
# edge: 1
# boundary: [(7, 5, (13, 5, 7)), (5, 19, (19, 5, 10))]
# ----------
# temp: (21, 5, 19)
# tri_op: (21, 19, 16)
# not in bad
# edge: 2
# boundary: [(7, 5, (13, 5, 7)), (5, 19, (19, 5, 10)), (19, 21, (21, 19, 16))]
# ----------
# temp: (21, 5, 19)
# tri_op: (21, 17, 5)
# in bad
# edge: 2
# temp: (21, 17, 5)
# ----------
# temp: (21, 17, 5)
# tri_op: (21, 15, 17)
# not in bad
# edge: 0
# boundary: [(7, 5, (13, 5, 7)), (5, 19, (19, 5, 10)), (19, 21, (21, 19, 16)), (21, 17, (21, 15, 17))]
# ----------
# temp: (21, 17, 5)
# tri_op: (17, 7, 5)
# in bad
# edge: 2
# temp: (17, 7, 5)
# ----------
# temp: (17, 7, 5)
# tri_op: (27, 7, 17)
# not in bad
# edge: 0
# boundary: [(7, 5, (13, 5, 7)), (5, 19, (19, 5, 10)), (19, 21, (21, 19, 16)), (21, 17, (21, 15, 17)), (17, 7, (27, 7, 17))]
# ----------
# coords[ 31 ] -> [237.89002739 932.57374806]
# ----------
# temp: (28, 23, 8)
# tri_op: (23, 9, 8)
# not in bad
# edge: 1
# boundary: [(23, 8, (23, 9, 8))]
# ----------
# temp: (28, 23, 8)
# tri_op: (28, 8, 15)
# in bad
# edge: 0
# temp: (28, 8, 15)
# ----------
# temp: (28, 8, 15)
# tri_op: (27, 15, 8)
# not in bad
# edge: 1
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8))]
# ----------
# temp: (28, 8, 15)
# tri_op: (28, 15, 11)
# not in bad
# edge: 2
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 28, (28, 15, 11))]
# ----------
# temp: (28, 8, 15)
# tri_op: (28, 23, 8)
# in bad
# edge: 2
# temp: (28, 23, 8)
# ----------
# temp: (28, 23, 8)
# tri_op: (28, 11, 23)
# not in bad
# edge: 0
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 28, (28, 15, 11)), (28, 23, (28, 11, 23))]
# ----------
# coords[ 32 ] -> [837.03815341 625.4170518 ]
# ----------
# temp: (19, 5, 10)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5))]
# ----------
# temp: (19, 5, 10)
# tri_op: (29, 19, 10)
# not in bad
# edge: 2
# boundary: [(5, 10, (13, 10, 5)), (10, 19, (29, 19, 10))]
# ----------
# temp: (19, 5, 10)
# tri_op: (30, 5, 19)
# in bad
# edge: 1
# temp: (30, 5, 19)
# ----------
# temp: (30, 5, 19)
# tri_op: (30, 19, 21)
# in bad
# edge: 0
# temp: (30, 19, 21)
# ----------
# temp: (30, 19, 21)
# tri_op: (21, 19, 16)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5)), (10, 19, (29, 19, 10)), (19, 21, (21, 19, 16))]
# ----------
# temp: (30, 19, 21)
# tri_op: (30, 21, 17)
# not in bad
# edge: 2
# boundary: [(5, 10, (13, 10, 5)), (10, 19, (29, 19, 10)), (19, 21, (21, 19, 16)), (21, 30, (30, 21, 17))]
# ----------
# temp: (30, 19, 21)
# tri_op: (30, 5, 19)
# in bad
# edge: 2
# temp: (30, 5, 19)
# ----------
# temp: (30, 5, 19)
# tri_op: (30, 7, 5)
# not in bad
# edge: 0
# boundary: [(5, 10, (13, 10, 5)), (10, 19, (29, 19, 10)), (19, 21, (21, 19, 16)), (21, 30, (30, 21, 17)), (30, 5, (30, 7, 5))]
# ----------
# coords[ 33 ] -> [593.94913466 734.96286069]
# ----------
# temp: (27, 7, 17)
# tri_op: (30, 17, 7)
# in bad
# edge: 1
# temp: (30, 17, 7)
# ----------
# temp: (30, 17, 7)
# tri_op: (30, 7, 5)
# in bad
# edge: 0
# temp: (30, 7, 5)
# ----------
# temp: (30, 7, 5)
# tri_op: (13, 5, 7)
# not in bad
# edge: 1
# boundary: [(7, 5, (13, 5, 7))]
# ----------
# temp: (30, 7, 5)
# tri_op: (32, 30, 5)
# not in bad
# edge: 2
# boundary: [(7, 5, (13, 5, 7)), (5, 30, (32, 30, 5))]
# ----------
# temp: (30, 7, 5)
# tri_op: (30, 17, 7)
# in bad
# edge: 2
# temp: (30, 17, 7)
# ----------
# temp: (30, 17, 7)
# tri_op: (30, 21, 17)
# not in bad
# edge: 0
# boundary: [(7, 5, (13, 5, 7)), (5, 30, (32, 30, 5)), (30, 17, (30, 21, 17))]
# ----------
# temp: (30, 17, 7)
# tri_op: (27, 7, 17)
# in bad
# edge: 1
# temp: (27, 7, 17)
# ----------
# temp: (27, 7, 17)
# tri_op: (27, 17, 15)
# not in bad
# edge: 2
# boundary: [(7, 5, (13, 5, 7)), (5, 30, (32, 30, 5)), (30, 17, (30, 21, 17)), (17, 27, (27, 17, 15))]
# ----------
# temp: (27, 7, 17)
# tri_op: (27, 9, 7)
# not in bad
# edge: 0
# boundary: [(7, 5, (13, 5, 7)), (5, 30, (32, 30, 5)), (30, 17, (30, 21, 17)), (17, 27, (27, 17, 15)), (27, 7, (27, 9, 7))]
# ----------
# coords[ 34 ] -> [419.86610228 307.36426937]
# ----------
# temp: (14, 6, 12)
# tri_op: (20, 12, 6)
# not in bad
# edge: 1
# boundary: [(6, 12, (20, 12, 6))]
# ----------
# temp: (14, 6, 12)
# tri_op: (14, 12, 4)
# in bad
# edge: 0
# temp: (14, 12, 4)
# ----------
# temp: (14, 12, 4)
# tri_op: (22, 4, 12)
# in bad
# edge: 1
# temp: (22, 4, 12)
# ----------
# temp: (22, 4, 12)
# tri_op: (22, 12, 20)
# not in bad
# edge: 2
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20))]
# ----------
# temp: (22, 4, 12)
# tri_op: (22, 9, 4)
# in bad
# edge: 2
# temp: (22, 9, 4)
# ----------
# temp: (22, 9, 4)
# tri_op: (25, 9, 22)
# in bad
# edge: 1
# temp: (25, 9, 22)
# ----------
# temp: (25, 9, 22)
# tri_op: (29, 25, 22)
# not in bad
# edge: 2
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22))]
# ----------
# temp: (25, 9, 22)
# tri_op: (25, 13, 9)
# in bad
# edge: 2
# temp: (25, 13, 9)
# ----------
# temp: (25, 13, 9)
# tri_op: (25, 10, 13)
# not in bad
# edge: 0
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22)), (25, 13, (25, 10, 13))]
# ----------
# temp: (25, 13, 9)
# tri_op: (13, 7, 9)
# not in bad
# edge: 1
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22)), (25, 13, (25, 10, 13)), (13, 9, (13, 7, 9))]
# ----------
# temp: (25, 13, 9)
# tri_op: (25, 9, 22)
# in bad
# edge: 0
# temp: (25, 9, 22)
# ----------
# temp: (25, 9, 22)
# tri_op: (22, 9, 4)
# in bad
# edge: 0
# temp: (22, 9, 4)
# ----------
# temp: (22, 9, 4)
# tri_op: (23, 4, 9)
# not in bad
# edge: 1
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22)), (25, 13, (25, 10, 13)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9))]
# ----------
# temp: (22, 9, 4)
# tri_op: (22, 4, 12)
# in bad
# edge: 0
# temp: (22, 4, 12)
# ----------
# temp: (22, 4, 12)
# tri_op: (14, 12, 4)
# in bad
# edge: 1
# temp: (14, 12, 4)
# ----------
# temp: (14, 12, 4)
# tri_op: (24, 14, 4)
# not in bad
# edge: 2
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22)), (25, 13, (25, 10, 13)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 14, (24, 14, 4))]
# ----------
# temp: (14, 12, 4)
# tri_op: (14, 6, 12)
# in bad
# edge: 2
# temp: (14, 6, 12)
# ----------
# temp: (14, 6, 12)
# tri_op: (14, 0, 6)
# not in bad
# edge: 0
# boundary: [(6, 12, (20, 12, 6)), (12, 22, (22, 12, 20)), (22, 25, (29, 25, 22)), (25, 13, (25, 10, 13)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 14, (24, 14, 4)), (14, 6, (14, 0, 6))]
# ----------
# coords[ 35 ] -> [190.71154603  51.36171959]
# ----------
# temp: (14, 0, 6)
# tri_op: (20, 6, 0)
# not in bad
# edge: 1
# boundary: [(0, 6, (20, 6, 0))]
# ----------
# temp: (14, 0, 6)
# tri_op: (34, 14, 6)
# in bad
# edge: 1
# temp: (34, 14, 6)
# ----------
# temp: (34, 14, 6)
# tri_op: (34, 6, 12)
# not in bad
# edge: 2
# boundary: [(0, 6, (20, 6, 0)), (6, 34, (34, 6, 12))]
# ----------
# temp: (34, 14, 6)
# tri_op: (34, 4, 14)
# not in bad
# edge: 0
# boundary: [(0, 6, (20, 6, 0)), (6, 34, (34, 6, 12)), (34, 14, (34, 4, 14))]
# ----------
# temp: (34, 14, 6)
# tri_op: (14, 0, 6)
# in bad
# edge: 2
# temp: (14, 0, 6)
# ----------
# temp: (14, 0, 6)
# tri_op: (24, 0, 14)
# not in bad
# edge: 0
# boundary: [(0, 6, (20, 6, 0)), (6, 34, (34, 6, 12)), (34, 14, (34, 4, 14)), (14, 0, (24, 0, 14))]
# ----------
# coords[ 36 ] -> [521.13153488 547.41809276]
# ----------
# temp: (25, 10, 13)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(10, 13, (13, 10, 5))]
# ----------
# temp: (25, 10, 13)
# tri_op: (34, 25, 13)
# in bad
# edge: 1
# temp: (34, 25, 13)
# ----------
# temp: (34, 25, 13)
# tri_op: (34, 13, 9)
# in bad
# edge: 0
# temp: (34, 13, 9)
# ----------
# temp: (34, 13, 9)
# tri_op: (13, 7, 9)
# not in bad
# edge: 1
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9))]
# ----------
# temp: (34, 13, 9)
# tri_op: (34, 9, 4)
# in bad
# edge: 0
# temp: (34, 9, 4)
# ----------
# temp: (34, 9, 4)
# tri_op: (23, 4, 9)
# not in bad
# edge: 1
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9))]
# ----------
# temp: (34, 9, 4)
# tri_op: (34, 4, 14)
# not in bad
# edge: 2
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 34, (34, 4, 14))]
# ----------
# temp: (34, 9, 4)
# tri_op: (34, 13, 9)
# in bad
# edge: 2
# temp: (34, 13, 9)
# ----------
# temp: (34, 13, 9)
# tri_op: (34, 25, 13)
# in bad
# edge: 2
# temp: (34, 25, 13)
# ----------
# temp: (34, 25, 13)
# tri_op: (34, 22, 25)
# in bad
# edge: 2
# temp: (34, 22, 25)
# ----------
# temp: (34, 22, 25)
# tri_op: (34, 12, 22)
# not in bad
# edge: 0
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 34, (34, 4, 14)), (34, 22, (34, 12, 22))]
# ----------
# temp: (34, 22, 25)
# tri_op: (29, 25, 22)
# not in bad
# edge: 1
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 34, (34, 4, 14)), (34, 22, (34, 12, 22)), (22, 25, (29, 25, 22))]
# ----------
# temp: (34, 22, 25)
# tri_op: (34, 25, 13)
# in bad
# edge: 0
# temp: (34, 25, 13)
# ----------
# temp: (34, 25, 13)
# tri_op: (25, 10, 13)
# in bad
# edge: 2
# temp: (25, 10, 13)
# ----------
# temp: (25, 10, 13)
# tri_op: (25, 18, 10)
# not in bad
# edge: 0
# boundary: [(10, 13, (13, 10, 5)), (13, 9, (13, 7, 9)), (9, 4, (23, 4, 9)), (4, 34, (34, 4, 14)), (34, 22, (34, 12, 22)), (22, 25, (29, 25, 22)), (25, 10, (25, 18, 10))]
# ----------
# coords[ 37 ] -> [260.4129825  478.09468617]
# ----------
# temp: (23, 4, 9)
# tri_op: (36, 9, 4)
# in bad
# edge: 1
# temp: (36, 9, 4)
# ----------
# temp: (36, 9, 4)
# tri_op: (36, 4, 34)
# in bad
# edge: 0
# temp: (36, 4, 34)
# ----------
# temp: (36, 4, 34)
# tri_op: (34, 4, 14)
# in bad
# edge: 0
# temp: (34, 4, 14)
# ----------
# temp: (34, 4, 14)
# tri_op: (24, 14, 4)
# in bad
# edge: 1
# temp: (24, 14, 4)
# ----------
# temp: (24, 14, 4)
# tri_op: (24, 4, 23)
# not in bad
# edge: 2
# boundary: [(4, 24, (24, 4, 23))]
# ----------
# temp: (24, 14, 4)
# tri_op: (24, 0, 14)
# not in bad
# edge: 0
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14))]
# ----------
# temp: (24, 14, 4)
# tri_op: (34, 4, 14)
# in bad
# edge: 1
# temp: (34, 4, 14)
# ----------
# temp: (34, 4, 14)
# tri_op: (35, 34, 14)
# not in bad
# edge: 2
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14)), (14, 34, (35, 34, 14))]
# ----------
# temp: (34, 4, 14)
# tri_op: (36, 4, 34)
# in bad
# edge: 1
# temp: (36, 4, 34)
# ----------
# temp: (36, 4, 34)
# tri_op: (36, 34, 22)
# not in bad
# edge: 2
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14)), (14, 34, (35, 34, 14)), (34, 36, (36, 34, 22))]
# ----------
# temp: (36, 4, 34)
# tri_op: (36, 9, 4)
# in bad
# edge: 2
# temp: (36, 9, 4)
# ----------
# temp: (36, 9, 4)
# tri_op: (36, 13, 9)
# not in bad
# edge: 0
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14)), (14, 34, (35, 34, 14)), (34, 36, (36, 34, 22)), (36, 9, (36, 13, 9))]
# ----------
# temp: (36, 9, 4)
# tri_op: (23, 4, 9)
# in bad
# edge: 1
# temp: (23, 4, 9)
# ----------
# temp: (23, 4, 9)
# tri_op: (23, 9, 8)
# not in bad
# edge: 2
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14)), (14, 34, (35, 34, 14)), (34, 36, (36, 34, 22)), (36, 9, (36, 13, 9)), (9, 23, (23, 9, 8))]
# ----------
# temp: (23, 4, 9)
# tri_op: (24, 4, 23)
# not in bad
# edge: 0
# boundary: [(4, 24, (24, 4, 23)), (24, 14, (24, 0, 14)), (14, 34, (35, 34, 14)), (34, 36, (36, 34, 22)), (36, 9, (36, 13, 9)), (9, 23, (23, 9, 8)), (23, 4, (24, 4, 23))]
# ----------
# coords[ 38 ] -> [ 22.74626668 872.94803405]
# ----------
# temp: (24, 3, 0)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(3, 0, None)]
# ----------
# temp: (24, 3, 0)
# tri_op: (24, 0, 14)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 24, (24, 0, 14))]
# ----------
# temp: (24, 3, 0)
# tri_op: (24, 11, 3)
# in bad
# edge: 2
# temp: (24, 11, 3)
# ----------
# temp: (24, 11, 3)
# tri_op: (24, 23, 11)
# in bad
# edge: 2
# temp: (24, 23, 11)
# ----------
# temp: (24, 23, 11)
# tri_op: (24, 4, 23)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 24, (24, 0, 14)), (24, 23, (24, 4, 23))]
# ----------
# temp: (24, 23, 11)
# tri_op: (28, 11, 23)
# in bad
# edge: 1
# temp: (28, 11, 23)
# ----------
# temp: (28, 11, 23)
# tri_op: (31, 28, 23)
# in bad
# edge: 1
# temp: (31, 28, 23)
# ----------
# temp: (31, 28, 23)
# tri_op: (31, 23, 8)
# not in bad
# edge: 2
# boundary: [(3, 0, None), (0, 24, (24, 0, 14)), (24, 23, (24, 4, 23)), (23, 31, (31, 23, 8))]
# ----------
# temp: (31, 28, 23)
# tri_op: (31, 15, 28)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 24, (24, 0, 14)), (24, 23, (24, 4, 23)), (23, 31, (31, 23, 8)), (31, 28, (31, 15, 28))]
# ----------
# temp: (31, 28, 23)
# tri_op: (28, 11, 23)
# in bad
# edge: 2
# temp: (28, 11, 23)
# ----------
# temp: (28, 11, 23)
# tri_op: (28, 15, 11)
# not in bad
# edge: 0
# boundary: [(3, 0, None), (0, 24, (24, 0, 14)), (24, 23, (24, 4, 23)), (23, 31, (31, 23, 8)), (31, 28, (31, 15, 28)), (28, 11, (28, 15, 11))]
# ----------
# temp: (28, 11, 23)
# tri_op: (24, 23, 11)
# in bad
# edge: 1
# temp: (24, 23, 11)
# ----------
# temp: (24, 23, 11)
# tri_op: (24, 11, 3)
# in bad
# edge: 0
# temp: (24, 11, 3)
# ----------
# temp: (24, 11, 3)
# tri_op: (15, 3, 11)
# not in bad
# edge: 1
# boundary: [(3, 0, None), (0, 24, (24, 0, 14)), (24, 23, (24, 4, 23)), (23, 31, (31, 23, 8)), (31, 28, (31, 15, 28)), (28, 11, (28, 15, 11)), (11, 3, (15, 3, 11))]
# ----------
# coords[ 39 ] -> [272.08372514 932.87086537]
# ----------
# temp: (31, 23, 8)
# tri_op: (23, 9, 8)
# not in bad
# edge: 1
# boundary: [(23, 8, (23, 9, 8))]
# ----------
# temp: (31, 23, 8)
# tri_op: (31, 8, 15)
# in bad
# edge: 0
# temp: (31, 8, 15)
# ----------
# temp: (31, 8, 15)
# tri_op: (27, 15, 8)
# not in bad
# edge: 1
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8))]
# ----------
# temp: (31, 8, 15)
# tri_op: (31, 15, 28)
# in bad
# edge: 0
# temp: (31, 15, 28)
# ----------
# temp: (31, 15, 28)
# tri_op: (28, 15, 11)
# not in bad
# edge: 1
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 28, (28, 15, 11))]
# ----------
# temp: (31, 15, 28)
# tri_op: (38, 31, 28)
# not in bad
# edge: 2
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 28, (28, 15, 11)), (28, 31, (38, 31, 28))]
# ----------
# temp: (31, 15, 28)
# tri_op: (31, 8, 15)
# in bad
# edge: 2
# temp: (31, 8, 15)
# ----------
# temp: (31, 8, 15)
# tri_op: (31, 23, 8)
# in bad
# edge: 2
# temp: (31, 23, 8)
# ----------
# temp: (31, 23, 8)
# tri_op: (38, 23, 31)
# not in bad
# edge: 0
# boundary: [(23, 8, (23, 9, 8)), (8, 15, (27, 15, 8)), (15, 28, (28, 15, 11)), (28, 31, (38, 31, 28)), (31, 23, (38, 23, 31))]
# ----------
# coords[ 40 ] -> [815.75929813 660.36657607]
# ----------
# temp: (32, 5, 10)
# tri_op: (13, 10, 5)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5))]
# ----------
# temp: (32, 5, 10)
# tri_op: (32, 10, 19)
# not in bad
# edge: 2
# boundary: [(5, 10, (13, 10, 5)), (10, 32, (32, 10, 19))]
# ----------
# temp: (32, 5, 10)
# tri_op: (32, 30, 5)
# in bad
# edge: 2
# temp: (32, 30, 5)
# ----------
# temp: (32, 30, 5)
# tri_op: (32, 21, 30)
# in bad
# edge: 2
# temp: (32, 21, 30)
# ----------
# temp: (32, 21, 30)
# tri_op: (32, 19, 21)
# not in bad
# edge: 0
# boundary: [(5, 10, (13, 10, 5)), (10, 32, (32, 10, 19)), (32, 21, (32, 19, 21))]
# ----------
# temp: (32, 21, 30)
# tri_op: (30, 21, 17)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5)), (10, 32, (32, 10, 19)), (32, 21, (32, 19, 21)), (21, 30, (30, 21, 17))]
# ----------
# temp: (32, 21, 30)
# tri_op: (32, 30, 5)
# in bad
# edge: 0
# temp: (32, 30, 5)
# ----------
# temp: (32, 30, 5)
# tri_op: (33, 5, 30)
# not in bad
# edge: 1
# boundary: [(5, 10, (13, 10, 5)), (10, 32, (32, 10, 19)), (32, 21, (32, 19, 21)), (21, 30, (30, 21, 17)), (30, 5, (33, 5, 30))]
# ----------
# coords[ 41 ] -> [663.10683801  81.41444904]
# ----------
# temp: (20, 12, 6)
# tri_op: (34, 6, 12)
# not in bad
# edge: 1
# boundary: [(12, 6, (34, 6, 12))]
# ----------
# temp: (20, 12, 6)
# tri_op: (20, 6, 0)
# not in bad
# edge: 2
# boundary: [(12, 6, (34, 6, 12)), (6, 20, (20, 6, 0))]
# ----------
# temp: (20, 12, 6)
# tri_op: (22, 12, 20)
# in bad
# edge: 1
# temp: (22, 12, 20)
# ----------
# temp: (22, 12, 20)
# tri_op: (26, 22, 20)
# in bad
# edge: 1
# temp: (26, 22, 20)
# ----------
# temp: (26, 22, 20)
# tri_op: (26, 20, 16)
# not in bad
# edge: 2
# boundary: [(12, 6, (34, 6, 12)), (6, 20, (20, 6, 0)), (20, 26, (26, 20, 16))]
# ----------
# temp: (26, 22, 20)
# tri_op: (29, 22, 26)
# in bad
# edge: 1
# temp: (29, 22, 26)
# ----------
# temp: (29, 22, 26)
# tri_op: (29, 26, 16)
# not in bad
# edge: 2
# boundary: [(12, 6, (34, 6, 12)), (6, 20, (20, 6, 0)), (20, 26, (26, 20, 16)), (26, 29, (29, 26, 16))]
# ----------
# temp: (29, 22, 26)
# tri_op: (29, 25, 22)
# not in bad
# edge: 0
# boundary: [(12, 6, (34, 6, 12)), (6, 20, (20, 6, 0)), (20, 26, (26, 20, 16)), (26, 29, (29, 26, 16)), (29, 22, (29, 25, 22))]
# ----------
# temp: (29, 22, 26)
# tri_op: (26, 22, 20)
# in bad
# edge: 0
# temp: (26, 22, 20)
# ----------
# temp: (26, 22, 20)
# tri_op: (22, 12, 20)
# in bad
# edge: 2
# temp: (22, 12, 20)
# ----------
# temp: (22, 12, 20)
# tri_op: (34, 12, 22)
# not in bad
# edge: 0
# boundary: [(12, 6, (34, 6, 12)), (6, 20, (20, 6, 0)), (20, 26, (26, 20, 16)), (26, 29, (29, 26, 16)), (29, 22, (29, 25, 22)), (22, 12, (34, 12, 22))]
# ----------
# coords[ 42 ] -> [495.56446597 898.81253968]
# ----------
# temp: (27, 17, 15)
# tri_op: (21, 15, 17)
# not in bad
# edge: 1
# boundary: [(17, 15, (21, 15, 17))]
# ----------
# temp: (27, 17, 15)
# tri_op: (27, 15, 8)
# in bad
# edge: 0
# temp: (27, 15, 8)
# ----------
# temp: (27, 15, 8)
# tri_op: (39, 8, 15)
# not in bad
# edge: 1
# boundary: [(17, 15, (21, 15, 17)), (15, 8, (39, 8, 15))]
# ----------
# temp: (27, 15, 8)
# tri_op: (27, 8, 9)
# not in bad
# edge: 2
# boundary: [(17, 15, (21, 15, 17)), (15, 8, (39, 8, 15)), (8, 27, (27, 8, 9))]
# ----------
# temp: (27, 15, 8)
# tri_op: (27, 17, 15)
# in bad
# edge: 2
# temp: (27, 17, 15)
# ----------
# temp: (27, 17, 15)
# tri_op: (33, 17, 27)
# not in bad
# edge: 0
# boundary: [(17, 15, (21, 15, 17)), (15, 8, (39, 8, 15)), (8, 27, (27, 8, 9)), (27, 17, (33, 17, 27))]
# ----------
# coords[ 43 ] -> [912.94343298 890.3269139 ]
# ----------
# temp: (21, 16, 2)
# tri_op: (16, 1, 2)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2))]
# ----------
# temp: (21, 16, 2)
# tri_op: (21, 2, 15)
# in bad
# edge: 0
# temp: (21, 2, 15)
# ----------
# temp: (21, 2, 15)
# tri_op: (15, 2, 3)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3))]
# ----------
# temp: (21, 2, 15)
# tri_op: (21, 15, 17)
# in bad
# edge: 0
# temp: (21, 15, 17)
# ----------
# temp: (21, 15, 17)
# tri_op: (42, 17, 15)
# not in bad
# edge: 1
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (42, 17, 15))]
# ----------
# temp: (21, 15, 17)
# tri_op: (30, 21, 17)
# in bad
# edge: 1
# temp: (30, 21, 17)
# ----------
# temp: (30, 21, 17)
# tri_op: (33, 30, 17)
# not in bad
# edge: 2
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (42, 17, 15)), (17, 30, (33, 30, 17))]
# ----------
# temp: (30, 21, 17)
# tri_op: (40, 21, 30)
# not in bad
# edge: 0
# boundary: [(16, 2, (16, 1, 2)), (2, 15, (15, 2, 3)), (15, 17, (42, 17, 15)), (17, 30, (33, 30, 17)), (30, 21, (40, 21, 30))]
# ----------
# temp: (30, 21, 17)
# tri_op: (21, 15, 17)
# in bad
# edge: 2
# temp: (21, 15, 17)
# ----------
# temp: (21, 15, 17)
# tri_op: (21, 2, 15)
# in bad
# edge: 2
# temp: (21, 2, 15)
# ----------
# temp: (21, 2, 15)
# tri_op: (21, 16, 2)
# in bad
# edge: 2
# temp: (21, 16, 2)
# ----------
# temp: (21, 16, 2)
# tri_op: (21, 19, 16)
# ...
# not in bad
# edge: 1
# boundary: [(12, 20, (20, 12, 9)), (20, 26, (26, 20, 9))]
# ----------
# temp: (27, 20, 26)
# tri_op: (27, 26, 15)
# in bad
# edge: 0
# temp: (27, 26, 15)
# ----------
# temp: (27, 26, 15)
# tri_op: (29, 15, 26)
# not in bad
# edge: 1
# boundary: [(12, 20, (20, 12, 9)), (20, 26, (26, 20, 9)), (26, 15, (29, 15, 26))]
# ----------
# temp: (27, 26, 15)
# tri_op: (27, 15, 21)
# not in bad
# edge: 2
# boundary: [(12, 20, (20, 12, 9)), (20, 26, (26, 20, 9)), (26, 15, (29, 15, 26)), (15, 27, (27, 15, 21))]
# ----------
# temp: (27, 26, 15)
# tri_op: (27, 20, 26)
# in bad
# edge: 2
# temp: (27, 20, 26)
# ----------
# temp: (27, 20, 26)
# tri_op: (27, 12, 20)
# in bad
# edge: 2
# temp: (27, 12, 20)
# ----------
# temp: (27, 12, 20)
# tri_op: (27, 1, 12)
# not in bad
# edge: 0
# boundary: [(12, 20, (20, 12, 9)), (20, 26, (26, 20, 9)), (26, 15, (29, 15, 26)), (15, 27, (27, 15, 21)), (27, 12, (27, 1, 12))]
# ----------
# Inserting seed 40 [227.84438527 966.292637  ]
# coords[ 44 ] -> [227.84438527 966.292637  ]
# ----------
# temp: (24, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(2, 3, None)]
# ----------
# temp: (24, 2, 3)
# tri_op: (25, 24, 3)
# in bad
# edge: 1
# temp: (25, 24, 3)
# ----------
# temp: (25, 24, 3)
# tri_op: (25, 3, 0)
# not in bad
# edge: 2
# boundary: [(2, 3, None), (3, 25, (25, 3, 0))]
# ----------
# temp: (25, 24, 3)
# tri_op: (35, 24, 25)
# in bad
# edge: 1
# temp: (35, 24, 25)
# ----------
# temp: (35, 24, 25)
# tri_op: (35, 25, 16)
# not in bad
# edge: 2
# boundary: [(2, 3, None), (3, 25, (25, 3, 0)), (25, 35, (35, 25, 16))]
# ----------
# temp: (35, 24, 25)
# tri_op: (39, 24, 35)
# not in bad
# edge: 0
# boundary: [(2, 3, None), (3, 25, (25, 3, 0)), (25, 35, (35, 25, 16)), (35, 24, (39, 24, 35))]
# ----------
# temp: (35, 24, 25)
# tri_op: (25, 24, 3)
# in bad
# edge: 0
# temp: (25, 24, 3)
# ----------
# temp: (25, 24, 3)
# tri_op: (24, 2, 3)
# in bad
# edge: 2
# temp: (24, 2, 3)
# ----------
# temp: (24, 2, 3)
# tri_op: (24, 22, 2)
# not in bad
# edge: 0
# boundary: [(2, 3, None), (3, 25, (25, 3, 0)), (25, 35, (35, 25, 16)), (35, 24, (39, 24, 35)), (24, 2, (24, 22, 2))]
# ----------
# Inserting seed 41 [987.57022232 444.96677554]
# coords[ 45 ] -> [987.57022232 444.96677554]
# ----------
# temp: (20, 12, 9)
# tri_op: (34, 9, 12)
# in bad
# edge: 1
# temp: (34, 9, 12)
# ----------
# temp: (34, 9, 12)
# tri_op: (34, 12, 2)
# not in bad
# edge: 2
# boundary: [(12, 34, (34, 12, 2))]
# ----------
# temp: (34, 9, 12)
# tri_op: (34, 11, 9)
# in bad
# edge: 2
# temp: (34, 11, 9)
# ----------
# temp: (34, 11, 9)
# tri_op: (41, 11, 34)
# not in bad
# edge: 0
# boundary: [(12, 34, (34, 12, 2)), (34, 11, (41, 11, 34))]
# ----------
# temp: (34, 11, 9)
# tri_op: (26, 9, 11)
# not in bad
# edge: 1
# boundary: [(12, 34, (34, 12, 2)), (34, 11, (41, 11, 34)), (11, 9, (26, 9, 11))]
# ----------
# temp: (34, 11, 9)
# tri_op: (34, 9, 12)
# in bad
# edge: 0
# temp: (34, 9, 12)
# ----------
# temp: (34, 9, 12)
# tri_op: (20, 12, 9)
# in bad
# edge: 1
# temp: (20, 12, 9)
# ----------
# temp: (20, 12, 9)
# tri_op: (26, 20, 9)
# not in bad
# edge: 2
# boundary: [(12, 34, (34, 12, 2)), (34, 11, (41, 11, 34)), (11, 9, (26, 9, 11)), (9, 20, (26, 20, 9))]
# ----------
# temp: (20, 12, 9)
# tri_op: (43, 12, 20)
# not in bad
# edge: 0
# boundary: [(12, 34, (34, 12, 2)), (34, 11, (41, 11, 34)), (11, 9, (26, 9, 11)), (9, 20, (26, 20, 9)), (20, 12, (43, 12, 20))]
# ----------
# Inserting seed 42 [614.34585432 391.915311  ]
# coords[ 46 ] -> [614.34585432 391.915311  ]
# ----------
# temp: (28, 8, 26)
# tri_op: (40, 26, 8)
# in bad
# edge: 1
# temp: (40, 26, 8)
# ----------
# temp: (40, 26, 8)
# tri_op: (40, 8, 13)
# not in bad
# edge: 2
# boundary: [(8, 40, (40, 8, 13))]
# ----------
# temp: (40, 26, 8)
# tri_op: (40, 29, 26)
# in bad
# edge: 2
# temp: (40, 29, 26)
# ----------
# temp: (40, 29, 26)
# tri_op: (40, 31, 29)
# not in bad
# edge: 0
# boundary: [(8, 40, (40, 8, 13)), (40, 29, (40, 31, 29))]
# ----------
# temp: (40, 29, 26)
# tri_op: (29, 15, 26)
# not in bad
# edge: 1
# boundary: [(8, 40, (40, 8, 13)), (40, 29, (40, 31, 29)), (29, 26, (29, 15, 26))]
# ----------
# temp: (40, 29, 26)
# tri_op: (40, 26, 8)
# in bad
# edge: 0
# temp: (40, 26, 8)
# ----------
# temp: (40, 26, 8)
# tri_op: (28, 8, 26)
# in bad
# edge: 1
# temp: (28, 8, 26)
# ----------
# temp: (28, 8, 26)
# tri_op: (28, 26, 11)
# not in bad
# edge: 2
# boundary: [(8, 40, (40, 8, 13)), (40, 29, (40, 31, 29)), (29, 26, (29, 15, 26)), (26, 28, (28, 26, 11))]
# ----------
# temp: (28, 8, 26)
# tri_op: (28, 10, 8)
# in bad
# edge: 2
# temp: (28, 10, 8)
# ----------
# temp: (28, 10, 8)
# tri_op: (28, 7, 10)
# not in bad
# edge: 0
# boundary: [(8, 40, (40, 8, 13)), (40, 29, (40, 31, 29)), (29, 26, (29, 15, 26)), (26, 28, (28, 26, 11)), (28, 10, (28, 7, 10))]
# ----------
# temp: (28, 10, 8)
# tri_op: (19, 8, 10)
# not in bad
# edge: 1
# boundary: [(8, 40, (40, 8, 13)), (40, 29, (40, 31, 29)), (29, 26, (29, 15, 26)), (26, 28, (28, 26, 11)), (28, 10, (28, 7, 10)), (10, 8, (19, 8, 10))]
# ----------
# Inserting seed 43 [327.28309801 910.89318658]
# coords[ 47 ] -> [327.28309801 910.89318658]
# ----------
# temp: (39, 19, 22)
# tri_op: (22, 19, 10)
# not in bad
# edge: 1
# boundary: [(19, 22, (22, 19, 10))]
# ----------
# temp: (39, 19, 22)
# tri_op: (39, 22, 24)
# in bad
# edge: 0
# temp: (39, 22, 24)
# ----------
# temp: (39, 22, 24)
# tri_op: (24, 22, 2)
# not in bad
# edge: 1
# boundary: [(19, 22, (22, 19, 10)), (22, 24, (24, 22, 2))]
# ----------
# temp: (39, 22, 24)
# tri_op: (39, 24, 35)
# in bad
# edge: 0
# temp: (39, 24, 35)
# ----------
# temp: (39, 24, 35)
# tri_op: (44, 35, 24)
# in bad
# edge: 1
# temp: (44, 35, 24)
# ----------
# temp: (44, 35, 24)
# tri_op: (44, 24, 2)
# not in bad
# edge: 2
# boundary: [(19, 22, (22, 19, 10)), (22, 24, (24, 22, 2)), (24, 44, (44, 24, 2))]
# ----------
# temp: (44, 35, 24)
# tri_op: (44, 25, 35)
# not in bad
# edge: 0
# boundary: [(19, 22, (22, 19, 10)), (22, 24, (24, 22, 2)), (24, 44, (44, 24, 2)), (44, 35, (44, 25, 35))]
# ----------
# temp: (44, 35, 24)
# tri_op: (39, 24, 35)
# in bad
# edge: 1
# temp: (39, 24, 35)
# ----------
# temp: (39, 24, 35)
# tri_op: (39, 35, 32)
# not in bad
# edge: 2
# boundary: [(19, 22, (22, 19, 10)), (22, 24, (24, 22, 2)), (24, 44, (44, 24, 2)), (44, 35, (44, 25, 35)), (35, 39, (39, 35, 32))]
# ----------
# temp: (39, 24, 35)
# tri_op: (39, 22, 24)
# in bad
# edge: 2
# temp: (39, 22, 24)
# ----------
# temp: (39, 22, 24)
# tri_op: (39, 19, 22)
# in bad
# edge: 2
# temp: (39, 19, 22)
# ----------
# temp: (39, 19, 22)
# tri_op: (39, 23, 19)
# not in bad
# edge: 0
# boundary: [(19, 22, (22, 19, 10)), (22, 24, (24, 22, 2)), (24, 44, (44, 24, 2)), (44, 35, (44, 25, 35)), (35, 39, (39, 35, 32)), (39, 19, (39, 23, 19))]
# ----------
# Inserting seed 44 [755.65885686 988.01214006]
# coords[ 48 ] -> [755.65885686 988.01214006]
# ----------
# temp: (24, 22, 2)
# tri_op: (36, 2, 22)
# in bad
# edge: 1
# temp: (36, 2, 22)
# ----------
# temp: (36, 2, 22)
# tri_op: (36, 22, 10)
# in bad
# edge: 0
# temp: (36, 22, 10)
# ----------
# temp: (36, 22, 10)
# tri_op: (22, 19, 10)
# not in bad
# edge: 1
# boundary: [(22, 10, (22, 19, 10))]
# ----------
# temp: (36, 22, 10)
# tri_op: (41, 36, 10)
# not in bad
# edge: 2
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10))]
# ----------
# temp: (36, 22, 10)
# tri_op: (36, 2, 22)
# in bad
# edge: 2
# temp: (36, 2, 22)
# ----------
# temp: (36, 2, 22)
# tri_op: (36, 34, 2)
# in bad
# edge: 2
# temp: (36, 34, 2)
# ----------
# temp: (36, 34, 2)
# tri_op: (41, 34, 36)
# not in bad
# edge: 0
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36))]
# ----------
# temp: (36, 34, 2)
# tri_op: (34, 12, 2)
# not in bad
# edge: 1
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36)), (34, 2, (34, 12, 2))]
# ----------
# temp: (36, 34, 2)
# tri_op: (36, 2, 22)
# in bad
# edge: 0
# temp: (36, 2, 22)
# ----------
# temp: (36, 2, 22)
# tri_op: (24, 22, 2)
# in bad
# edge: 1
# temp: (24, 22, 2)
# ----------
# temp: (24, 22, 2)
# tri_op: (44, 24, 2)
# in bad
# edge: 1
# temp: (44, 24, 2)
# ----------
# temp: (44, 24, 2)
# tri_op: (44, 2, 3)
# in bad
# edge: 0
# temp: (44, 2, 3)
# ----------
# temp: (44, 2, 3)
# tri_op: None
# not in bad
# edge: 1
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36)), (34, 2, (34, 12, 2)), (2, 3, None)]
# ----------
# temp: (44, 2, 3)
# tri_op: (44, 3, 25)
# not in bad
# edge: 2
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36)), (34, 2, (34, 12, 2)), (2, 3, None), (3, 44, (44, 3, 25))]
# ----------
# temp: (44, 2, 3)
# tri_op: (44, 24, 2)
# in bad
# edge: 2
# temp: (44, 24, 2)
# ----------
# temp: (44, 24, 2)
# tri_op: (47, 24, 44)
# not in bad
# edge: 0
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36)), (34, 2, (34, 12, 2)), (2, 3, None), (3, 44, (44, 3, 25)), (44, 24, (47, 24, 44))]
# ----------
# temp: (44, 24, 2)
# tri_op: (24, 22, 2)
# in bad
# edge: 2
# temp: (24, 22, 2)
# ----------
# temp: (24, 22, 2)
# tri_op: (47, 22, 24)
# not in bad
# edge: 0
# boundary: [(22, 10, (22, 19, 10)), (10, 36, (41, 36, 10)), (36, 34, (41, 34, 36)), (34, 2, (34, 12, 2)), (2, 3, None), (3, 44, (44, 3, 25)), (44, 24, (47, 24, 44)), (24, 22, (47, 22, 24))]
# ----------
# Inserting seed 45 [405.36595966 236.00559417]
# coords[ 49 ] -> [405.36595966 236.00559417]
# ----------
# temp: (31, 13, 4)
# tri_op: (14, 4, 13)
# not in bad
# edge: 1
# boundary: [(13, 4, (14, 4, 13))]
# ----------
# temp: (31, 13, 4)
# tri_op: (42, 31, 4)
# not in bad
# edge: 2
# boundary: [(13, 4, (14, 4, 13)), (4, 31, (42, 31, 4))]
# ----------
# temp: (31, 13, 4)
# tri_op: (40, 13, 31)
# not in bad
# edge: 0
# boundary: [(13, 4, (14, 4, 13)), (4, 31, (42, 31, 4)), (31, 13, (40, 13, 31))]
# ----------
# Inserting seed 46 [764.08380664 740.23333485]
# coords[ 50 ] -> [764.08380664 740.23333485]
# ----------
# temp: (22, 19, 10)
# tri_op: (19, 8, 10)
# not in bad
# edge: 1
# boundary: [(19, 10, (19, 8, 10))]
# ----------
# temp: (22, 19, 10)
# tri_op: (48, 22, 10)
# in bad
# edge: 1
# temp: (48, 22, 10)
# ----------
# temp: (48, 22, 10)
# tri_op: (48, 10, 36)
# in bad
# edge: 0
# temp: (48, 10, 36)
# ----------
# temp: (48, 10, 36)
# tri_op: (41, 36, 10)
# in bad
# edge: 1
# temp: (41, 36, 10)
# ----------
# temp: (41, 36, 10)
# tri_op: (41, 10, 7)
# not in bad
# edge: 2
# boundary: [(19, 10, (19, 8, 10)), (10, 41, (41, 10, 7))]
# ----------
# temp: (41, 36, 10)
# tri_op: (41, 34, 36)
# not in bad
# edge: 0
# boundary: [(19, 10, (19, 8, 10)), (10, 41, (41, 10, 7)), (41, 36, (41, 34, 36))]
# ----------
# temp: (41, 36, 10)
# tri_op: (48, 10, 36)
# in bad
# edge: 1
# temp: (48, 10, 36)
# ----------
# temp: (48, 10, 36)
# tri_op: (48, 36, 34)
# not in bad
# edge: 2
# boundary: [(19, 10, (19, 8, 10)), (10, 41, (41, 10, 7)), (41, 36, (41, 34, 36)), (36, 48, (48, 36, 34))]
# ----------
# temp: (48, 10, 36)
# tri_op: (48, 22, 10)
# in bad
# edge: 2
# temp: (48, 22, 10)
# ----------
# temp: (48, 22, 10)
# tri_op: (48, 24, 22)
# not in bad
# edge: 0
# boundary: [(19, 10, (19, 8, 10)), (10, 41, (41, 10, 7)), (41, 36, (41, 34, 36)), (36, 48, (48, 36, 34)), (48, 22, (48, 24, 22))]
# ----------
# temp: (48, 22, 10)
# tri_op: (22, 19, 10)
# in bad
# edge: 2
# temp: (22, 19, 10)
# ----------
# temp: (22, 19, 10)
# tri_op: (47, 19, 22)
# not in bad
# edge: 0
# boundary: [(19, 10, (19, 8, 10)), (10, 41, (41, 10, 7)), (41, 36, (41, 34, 36)), (36, 48, (48, 36, 34)), (48, 22, (48, 24, 22)), (22, 19, (47, 19, 22))]
# ----------
# Inserting seed 47 [744.26453018 141.06881188]
# coords[ 51 ] -> [744.26453018 141.06881188]
# ----------
# temp: (29, 15, 26)
# tri_op: (43, 26, 15)
# in bad
# edge: 1
# temp: (43, 26, 15)
# ----------
# temp: (43, 26, 15)
# tri_op: (43, 15, 27)
# in bad
# edge: 0
# temp: (43, 15, 27)
# ----------
# temp: (43, 15, 27)
# tri_op: (27, 15, 21)
# not in bad
# edge: 1
# boundary: [(15, 27, (27, 15, 21))]
# ----------
# temp: (43, 15, 27)
# tri_op: (43, 27, 12)
# not in bad
# edge: 2
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12))]
# ----------
# temp: (43, 15, 27)
# tri_op: (43, 26, 15)
# in bad
# edge: 2
# temp: (43, 26, 15)
# ----------
# temp: (43, 26, 15)
# tri_op: (43, 20, 26)
# in bad
# edge: 2
# temp: (43, 20, 26)
# ----------
# temp: (43, 20, 26)
# tri_op: (43, 12, 20)
# in bad
# edge: 2
# temp: (43, 12, 20)
# ----------
# temp: (43, 12, 20)
# tri_op: (43, 27, 12)
# not in bad
# edge: 0
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12)), (43, 12, (43, 27, 12))]
# ----------
# temp: (43, 12, 20)
# tri_op: (45, 20, 12)
# not in bad
# edge: 1
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12)), (43, 12, (43, 27, 12)), (12, 20, (45, 20, 12))]
# ----------
# temp: (43, 12, 20)
# tri_op: (43, 20, 26)
# in bad
# edge: 0
# temp: (43, 20, 26)
# ----------
# temp: (43, 20, 26)
# tri_op: (26, 20, 9)
# not in bad
# edge: 1
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12)), (43, 12, (43, 27, 12)), (12, 20, (45, 20, 12)), (20, 26, (26, 20, 9))]
# ----------
# temp: (43, 20, 26)
# tri_op: (43, 26, 15)
# in bad
# edge: 0
# temp: (43, 26, 15)
# ----------
# temp: (43, 26, 15)
# tri_op: (29, 15, 26)
# in bad
# edge: 1
# temp: (29, 15, 26)
# ----------
# temp: (29, 15, 26)
# tri_op: (46, 29, 26)
# not in bad
# edge: 2
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12)), (43, 12, (43, 27, 12)), (12, 20, (45, 20, 12)), (20, 26, (26, 20, 9)), (26, 29, (46, 29, 26))]
# ----------
# temp: (29, 15, 26)
# tri_op: (30, 15, 29)
# not in bad
# edge: 0
# boundary: [(15, 27, (27, 15, 21)), (27, 43, (43, 27, 12)), (43, 12, (43, 27, 12)), (12, 20, (45, 20, 12)), (20, 26, (26, 20, 9)), (26, 29, (46, 29, 26)), (29, 15, (30, 15, 29))]
# ----------
# Inserting seed 48 [ 97.4666989  686.00926336]
# coords[ 52 ] -> [ 97.4666989  686.00926336]
# ----------
# temp: (35, 16, 14)
# tri_op: (16, 4, 14)
# not in bad
# edge: 1
# boundary: [(16, 14, (16, 4, 14))]
# ----------
# temp: (35, 16, 14)
# tri_op: (35, 14, 32)
# in bad
# edge: 0
# temp: (35, 14, 32)
# ----------
# temp: (35, 14, 32)
# tri_op: (32, 14, 13)
# not in bad
# edge: 1
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13))]
# ----------
# temp: (35, 14, 32)
# tri_op: (39, 35, 32)
# in bad
# edge: 1
# temp: (39, 35, 32)
# ----------
# temp: (39, 35, 32)
# tri_op: (39, 32, 6)
# not in bad
# edge: 2
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13)), (32, 39, (39, 32, 6))]
# ----------
# temp: (39, 35, 32)
# tri_op: (47, 35, 39)
# in bad
# edge: 1
# temp: (47, 35, 39)
# ----------
# temp: (47, 35, 39)
# tri_op: (47, 39, 19)
# not in bad
# edge: 2
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13)), (32, 39, (39, 32, 6)), (39, 47, (47, 39, 19))]
# ----------
# temp: (47, 35, 39)
# tri_op: (47, 44, 35)
# not in bad
# edge: 0
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13)), (32, 39, (39, 32, 6)), (39, 47, (47, 39, 19)), (47, 35, (47, 44, 35))]
# ----------
# temp: (47, 35, 39)
# tri_op: (39, 35, 32)
# in bad
# edge: 0
# temp: (39, 35, 32)
# ----------
# temp: (39, 35, 32)
# tri_op: (35, 14, 32)
# in bad
# edge: 2
# temp: (35, 14, 32)
# ----------
# temp: (35, 14, 32)
# tri_op: (35, 16, 14)
# in bad
# edge: 2
# temp: (35, 16, 14)
# ----------
# temp: (35, 16, 14)
# tri_op: (35, 25, 16)
# in bad
# edge: 2
# temp: (35, 25, 16)
# ----------
# temp: (35, 25, 16)
# tri_op: (44, 25, 35)
# not in bad
# edge: 0
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13)), (32, 39, (39, 32, 6)), (39, 47, (47, 39, 19)), (47, 35, (47, 44, 35)), (35, 25, (44, 25, 35))]
# ----------
# temp: (35, 25, 16)
# tri_op: (38, 16, 25)
# not in bad
# edge: 1
# boundary: [(16, 14, (16, 4, 14)), (14, 32, (32, 14, 13)), (32, 39, (39, 32, 6)), (39, 47, (47, 39, 19)), (47, 35, (47, 44, 35)), (35, 25, (44, 25, 35)), (25, 16, (38, 16, 25))]
# ----------
# Inserting seed 49 [822.3918168  285.85917452]
# coords[ 53 ] -> [822.3918168  285.85917452]
# ----------
# temp: (26, 20, 9)
# tri_op: (45, 9, 20)
# not in bad
# edge: 1
# boundary: [(20, 9, (45, 9, 20))]
# ----------
# temp: (26, 20, 9)
# tri_op: (26, 9, 11)
# not in bad
# edge: 2
# boundary: [(20, 9, (45, 9, 20)), (9, 26, (26, 9, 11))]
# ----------
# temp: (26, 20, 9)
# tri_op: (51, 20, 26)
# in bad
# edge: 1
# temp: (51, 20, 26)
# ----------
# temp: (51, 20, 26)
# tri_op: (51, 26, 29)
# in bad
# edge: 0
# temp: (51, 26, 29)
# ----------
# temp: (51, 26, 29)
# tri_op: (46, 29, 26)
# not in bad
# edge: 1
# boundary: [(20, 9, (45, 9, 20)), (9, 26, (26, 9, 11)), (26, 29, (46, 29, 26))]
# ----------
# temp: (51, 26, 29)
# tri_op: (51, 29, 15)
# not in bad
# edge: 2
# boundary: [(20, 9, (45, 9, 20)), (9, 26, (26, 9, 11)), (26, 29, (46, 29, 26)), (29, 51, (51, 29, 15))]
# ----------
# temp: (51, 26, 29)
# tri_op: (51, 20, 26)
# in bad
# edge: 2
# temp: (51, 20, 26)
# ----------
# temp: (51, 20, 26)
# tri_op: (51, 12, 20)
# in bad
# edge: 2
# temp: (51, 12, 20)
# ----------
# temp: (51, 12, 20)
# tri_op: (51, 43, 12)
# not in bad
# edge: 0
# boundary: [(20, 9, (45, 9, 20)), (9, 26, (26, 9, 11)), (26, 29, (46, 29, 26)), (29, 51, (51, 29, 15)), (51, 12, (51, 43, 12))]
# ----------
# temp: (51, 12, 20)
# tri_op: (45, 20, 12)
# not in bad
# edge: 1
# boundary: [(20, 9, (45, 9, 20)), (9, 26, (26, 9, 11)), (26, 29, (46, 29, 26)), (29, 51, (51, 29, 15)), (51, 12, (51, 43, 12)), (12, 20, (45, 20, 12))]
# ----------
